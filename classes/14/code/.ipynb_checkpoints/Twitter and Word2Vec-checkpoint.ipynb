# %% [markdown]
# # SF-DAT-21 |Tweets & Word2Vec (Lab)

# %% [markdown]
# # Gensim

# %% [markdown]
# Gensim (http://radimrehurek.com/gensim) is a library of language processing tools focused on latent variable models of text.

# %%
import os
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import feature_extraction
from gensim import matutils, models

pd.set_option('display.max_rows', 10)
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 10)

# %matplotlib inline
plt.style.use('ggplot')

# %% [markdown]
# The data is about sentiments on Amazon reviews.

# %%
content = []

with open(os.path.join('..', 'datasets', 'tweets.txt')) as f:
    for line in f.readlines():
        line = line.strip('\n')#
        content.append(line.lower())

#df = pd.DataFrame({'content': content})

# %%
df = pd.DataFrame({'content': content})

# %%
df.head()
# Out:
#                                              content
# 0  i made a(n) small tourmaline in paradise islan...
# 1  rt @purelovebeast: -เช็ครายละเอียด- 27th birth...
# 2                            https://t.co/eofbdvqufo
# 3                        @vigigu google it :) simple
# 4             nerd ass girl  https://t.co/t7kdirxpel

# %%
df.dropna(inplace = True) # Let's drop the NaN

# %%
df.head()
# Out:
#                                              content
# 0  i made a(n) small tourmaline in paradise islan...
# 1  rt @purelovebeast: -เช็ครายละเอียด- 27th birth...
# 2                            https://t.co/eofbdvqufo
# 3                        @vigigu google it :) simple
# 4             nerd ass girl  https://t.co/t7kdirxpel

# %% [markdown]
# ## LDA with Gensim

# %% [markdown]
# ### Let's first translate a set of documents (articles) into a matrix representation with a row per document and a column per feature (word or n-gram)

# %%
vectorizer = feature_extraction.text.CountVectorizer(stop_words = 'english')

# %%
documents = vectorizer.fit_transform(df.content)

# %%
df.content
# Out:
# 0       i made a(n) small tourmaline in paradise islan...
# 1       rt @purelovebeast: -เช็ครายละเอียด- 27th birth...
# 2                                 https://t.co/eofbdvqufo
# 3                             @vigigu google it :) simple
# 4                  nerd ass girl  https://t.co/t7kdirxpel
#                               ...
# 4888    tesla rival may be producing a batmobile-like ...
# 4889    mercedes-benz plans four new electric #tesla f...
# 4890    rt @hblodget: new tesla competitor is launchin...
# 4891    spacex rocket in great shape after historic la...
# 4892    new photos of spacex booster show sooty but un...
# Name: content, dtype: object

# %%
import re
j = 0
for i in df.content:
    df.content[j] = re.sub(r"http\S+", "", i)
    j = j + 1

# %%
df.content
# Out:
# 0       new photos of spacex booster show sooty but un...
# 1       rt @purelovebeast: -เช็ครายละเอียด- 27th birth...
# 2
# 3                             @vigigu google it :) simple
# 4                                         nerd ass girl
#                               ...
# 4888    tesla rival may be producing a batmobile-like ...
# 4889    mercedes-benz plans four new electric #tesla f...
# 4890    rt @hblodget: new tesla competitor is launchin...
# 4891    spacex rocket in great shape after historic la...
# 4892    new photos of spacex booster show sooty but un...
# Name: content, dtype: object

# %%
text = "this is an https://URL.com blah blah blah"
result = re.sub(r"http\S+", "", text)
result
# Out:
# 'this is an  blah blah blah'

# %%
df.content
# Out:
# 0       new photos of spacex booster show sooty but un...
# 1       rt @purelovebeast: -เช็ครายละเอียด- 27th birth...
# 2
# 3                             @vigigu google it :) simple
# 4                                         nerd ass girl
#                               ...
# 4888    tesla rival may be producing a batmobile-like ...
# 4889    mercedes-benz plans four new electric #tesla f...
# 4890    rt @hblodget: new tesla competitor is launchin...
# 4891    spacex rocket in great shape after historic la...
# 4892    new photos of spacex booster show sooty but un...
# Name: content, dtype: object

# %%
# Let's now build a mapping of numerical ID to word

id2word = dict(enumerate(vectorizer.get_feature_names()))

# %%
id2word
# Out:
# {0: u'00',
#  1: u'000',
#  2: u'00am',
#  3: u'01',
#  4: u'0161',
#  5: u'01c',
#  6: u'02',
#  7: u'034',
#  8: u'039',
#  9: u'04',
#  10: u'0430mayi',
#  11: u'0502',
#  12: u'0574',
#  13: u'06',
#  14: u'07',
#  15: u'10',
#  16: u'100',
#  17: u'1000',
#  18: u'100000',
#  19: u'1000s',
#  20: u'100bn',
#  21: u'100d',
#  22: u'100esquses',
#  23: u'100mp',
#  24: u'100s',
#  25: u'1010lt',
#  26: u'1028',
#  27: u'1091',
#  28: u'10pm',
#  29: u'11',
#  30: u'11000',
#  31: u'110k',
#  32: u'111',
#  33: u'1159pm',
#  34: u'1159pmpactm',
#  35: u'118',
#  36: u'11sixedits',
#  37: u'12',
#  38: u'1213',
#  39: u'123000',
#  40: u'125',
#  41: u'127',
#  42: u'1279',
#  43: u'1282048b33ba483',
#  44: u'12me',
#  45: u'13',
#  46: u'13000',
#  47: u'131',
#  48: u'1311',
#  49: u'132k',
#  50: u'14',
#  51: u'1439',
#  52: u'145',
#  53: u'1451886241',
#  54: u'148',
#  55: u'14gb',
#  56: u'14th',
#  57: u'15',
#  58: u'150',
#  59: u'1540',
#  60: u'1588days',
#  61: u'158b78679ddc4b6',
#  62: u'15gb',
#  63: u'16',
#  64: u'16000',
#  65: u'16gb',
#  66: u'16mile',
#  67: u'17',
#  68: u'1723091184',
#  69: u'1763210325',
#  70: u'1783',
#  71: u'17carat',
#  72: u'18',
#  73: u'1800',
#  74: u'1810',
#  75: u'1811',
#  76: u'1862185791',
#  77: u'1865846254',
#  78: u'19',
#  79: u'1942',
#  80: u'1957_tintin_',
#  81: u'1970s',
#  82: u'1977755529',
#  83: u'1979',
#  84: u'1980s',
#  85: u'1989',
#  86: u'1992',
#  87: u'1998',
#  88: u'1999',
#  89: u'19th',
#  90: u'1d',
#  91: u'1evilidiot',
#  92: u'1gb',
#  93: u'1jihn',
#  94: u'1linewed',
#  95: u'1novel',
#  96: u'1st',
#  97: u'20',
#  98: u'200',
#  99: u'2000',
#  100: u'2002',
#  101: u'2003',
#  102: u'2005',
#  103: u'2007',
#  104: u'2008',
#  105: u'2009',
#  106: u'2009y',
#  107: u'200d',
#  108: u'200m',
#  109: u'2010',
#  110: u'2011',
#  111: u'2012',
#  112: u'2013',
#  113: u'2014',
#  114: u'20140618',
#  115: u'2015',
#  116: u'2016',
#  117: u'2016tips',
#  118: u'2017',
#  119: u'2020',
#  120: u'2036',
#  121: u'204',
#  122: u'2046',
#  123: u'2052',
#  124: u'2053',
#  125: u'2054',
#  126: u'2057',
#  127: u'205a',
#  128: u'2060',
#  129: u'2062',
#  130: u'2086',
#  131: u'20d',
#  132: u'21',
#  133: u'2100mah',
#  134: u'2106',
#  135: u'21st',
#  136: u'22',
#  137: u'221',
#  138: u'2248048877',
#  139: u'225',
#  140: u'23',
#  141: u'2343598528',
#  142: u'236',
#  143: u'238',
#  144: u'24',
#  145: u'247',
#  146: u'25',
#  147: u'250',
#  148: u'25000',
#  149: u'250gb',
#  150: u'2512584150',
#  151: u'254',
#  152: u'2592041653',
#  153: u'25h',
#  154: u'25sm',
#  155: u'26',
#  156: u'265',
#  157: u'2699',
#  158: u'27',
#  159: u'2769',
#  160: u'27th',
#  161: u'28',
#  162: u'2880633443',
#  163: u'29',
#  164: u'2avag3',
#  165: u'2establish',
#  166: u'2gb',
#  167: u'2kjsofea',
#  168: u'2kyuhyun',
#  169: u'2mgovercsquared',
#  170: u'2military',
#  171: u'2nd',
#  172: u'2pac',
#  173: u'2pm',
#  174: u'2pmphilippines',
#  175: u'30',
#  176: u'3000',
#  177: u'302',
#  178: u'303',
#  179: u'3079',
#  180: u'30seclovelive',
#  181: u'310000',
#  182: u'31day2aclutterfreelife',
#  183: u'32',
#  184: u'320',
#  185: u'32gb',
#  186: u'32k',
#  187: u'33',
#  188: u'333',
#  189: u'34',
#  190: u'341',
#  191: u'35',
#  192: u'350',
#  193: u'352',
#  194: u'36',
#  195: u'360',
#  196: u'3636',
#  197: u'38',
#  198: u'39',
#  199: u'3d',
#  200: u'3ds',
#  201: u'3g',
#  202: u'3rd',
#  203: u'3unit',
#  204: u'40',
#  205: u'400',
#  206: u'40z',
#  207: u'41',
#  208: u'418000',
#  209: u'41810',
#  210: u'42',
#  211: u'420',
#  212: u'4255x2845px',
#  213: u'432',
#  214: u'44',
#  215: u'45',
#  216: u'46',
#  217: u'4623',
#  218: u'465mph',
#  219: u'47',
#  220: u'48',
#  221: u'4895',
#  222: u'499',
#  223: u'49ers',
#  224: u'4freedominiran',
#  225: u'4g',
#  226: u'4nn',
#  227: u'4s',
#  228: u'4th',
#  229: u'50',
#  230: u'500',
#  231: u'50000',
#  232: u'504bayou',
#  233: u'50d',
#  234: u'50k',
#  235: u'50mbit',
#  236: u'50vs50',
#  237: u'51',
#  238: u'5244',
#  239: u'541',
#  240: u'543',
#  241: u'55',
#  242: u'57',
#  243: u'58',
#  244: u'580m',
#  245: u'587',
#  246: u'59',
#  247: u'5950',
#  248: u'59am',
#  249: u'5c',
#  250: u'5eva',
#  251: u'5k',
#  252: u'5m',
#  253: u'5pm',
#  254: u'5s',
#  255: u'5x',
#  256: u'60',
#  257: u'6021',
#  258: u'630',
#  259: u'64',
#  260: u'641',
#  261: u'642',
#  262: u'64gb',
#  263: u'65',
#  264: u'6584lb',
#  265: u'66',
#  266: u'667',
#  267: u'69',
#  268: u'6p',
#  269: u'6pm',
#  270: u'6s',
#  271: u'70',
#  272: u'700',
#  273: u'70mm',
#  274: u'70s',
#  275: u'7111',
#  276: u'72',
#  277: u'7268',
#  278: u'73',
#  279: u'731',
#  280: u'7482',
#  281: u'75',
#  282: u'76',
#  283: u'77',
#  284: u'785',
#  285: u'79',
#  286: u'7910',
#  287: u'7pm',
#  288: u'7th',
#  289: u'80',
#  290: u'800',
#  291: u'8000',
#  292: u'8093',
#  293: u'80s',
#  294: u'80smetal',
#  295: u'82',
#  296: u'8217',
#  297: u'8230',
#  298: u'825',
#  299: u'84',
#  300: u'8439',
#  301: u'85',
#  302: u'850',
#  303: u'856mo_thiun',
#  304: u'867',
#  305: u'87',
#  306: u'88',
#  307: u'89',
#  308: u'8g',
#  309: u'8gb',
#  310: u'8k',
#  311: u'8x10',
#  312: u'90',
#  313: u'90s',
#  314: u'91sticker',
#  315: u'92',
#  316: u'92650',
#  317: u'928',
#  318: u'95',
#  319: u'950',
#  320: u'9568',
#  321: u'96',
#  322: u'9650',
#  323: u'97',
#  324: u'98',
#  325: u'981',
#  326: u'99',
#  327: u'9912980188',
#  328: u'9926170436',
#  329: u'9991',
#  330: u'9gag',
#  331: u'_17studio',
#  332: u'_____',
#  333: u'_andreaa1417',
#  334: u'_bruno_rod_',
#  335: u'_lightskingoddd',
#  336: u'_omgalexa',
#  337: u'_queenlioness_',
#  338: u'_queenselina_',
#  339: u'_rachaelmcclung',
#  340: u'_real_',
#  341: u'_sem',
#  342: u'_shockieee',
#  343: u'_silentbent_',
#  344: u'_snats',
#  345: u'_spraytan',
#  346: u'_valeria_anahi',
#  347: u'_violet218',
#  348: u'_zach_c',
#  349: u'a33',
#  350: u'a7rii',
#  351: u'a_manaf999',
#  352: u'aa',
#  353: u'aaa',
#  354: u'aaronkleinshow',
#  355: u'abashed',
#  356: u'abasnadimy',
#  357: u'abbey',
#  358: u'abbswinston',
#  359: u'abc',
#  360: u'abdulah_alasiri',
#  361: u'abdulahalshamri',
#  362: u'abeer3f',
#  363: u'abel',
#  364: u'abidifactor',
#  365: u'abigailbellair',
#  366: u'able',
#  367: u'abo',
#  368: u'abogomolov',
#  369: u'abroad',
#  370: u'absence',
#  371: u'absolutely',
#  372: u'absolutley',
#  373: u'absolutly',
#  374: u'abt',
#  375: u'abu',
#  376: u'abunass3r',
#  377: u'abuse',
#  378: u'abuses',
#  379: u'abusing',
#  380: u'abusive',
#  381: u'abutalal1793',
#  382: u'ac',
#  383: u'academy',
#  384: u'acaiabrese',
#  385: u'accelerates',
#  386: u'access',
#  387: u'accessories',
#  388: u'accident',
#  389: u'accidentally',
#  390: u'accidents',
#  391: u'accomplished',
#  392: u'accomplishments',
#  393: u'according',
#  394: u'account',
#  395: u'accounts',
#  396: u'accurate',
#  397: u'accuse',
#  398: u'accuses',
#  399: u'acebandage85',
#  400: u'achievement',
#  401: u'achieving',
#  402: u'acid',
#  403: u'acknowledges',
#  404: u'acn',
#  405: u'acquire',
#  406: u'acquired',
#  407: u'acquires',
#  408: u'acrylics',
#  409: u'act',
#  410: u'acting',
#  411: u'action',
#  412: u'actions',
#  413: u'active',
#  414: u'activist',
#  415: u'activists',
#  416: u'activities',
#  417: u'actor',
#  418: u'actor_jayamravi',
#  419: u'actual',
#  420: u'actualconversation',
#  421: u'actually',
#  422: u'ad',
#  423: u'adam',
#  424: u'adampeterssst',
#  425: u'adams',
#  426: u'adcenter',
#  427: u'add',
#  428: u'added',
#  429: u'addi',
#  430: u'addicted',
#  431: u'addictive',
#  432: u'adding',
#  433: u'additional',
#  434: u'address',
#  435: u'addresses',
#  436: u'addressing',
#  437: u'adds',
#  438: u'adelaideseosa',
#  439: u'adelaljubeir',
#  440: u'aden',
#  441: u'adjustments',
#  442: u'adl_national',
#  443: u'admin',
#  444: u'admits',
#  445: u'adnansixer',
#  446: u'adobeindex',
#  447: u'adopt',
#  448: u'adoption',
#  449: u'adrenaline351',
#  450: u'adrian',
#  451: u'adrianpeterson',
#  452: u'adrxano',
#  453: u'ads',
#  454: u'adsense',
#  455: u'adsit',
#  456: u'adtech',
#  457: u'adult_goth',
#  458: u'adults',
#  459: u'advance',
#  460: u'advanced',
#  461: u'advances',
#  462: u'adventure',
#  463: u'advertise',
#  464: u'advertising',
#  465: u'advice',
#  466: u'advised',
#  467: u'adviser',
#  468: u'advisor',
#  469: u'advocacy',
#  470: u'advocates',
#  471: u'advrosen',
#  472: u'adweek',
#  473: u'adwords',
#  474: u'adzebill',
#  475: u'aea2016',
#  476: u'aerial',
#  477: u'aesthetichalsey',
#  478: u'aethra',
#  479: u'af',
#  480: u'afalli',
#  481: u'afc',
#  482: u'affair',
#  483: u'affairs',
#  484: u'affected',
#  485: u'affects',
#  486: u'affiliate',
#  487: u'affixpics',
#  488: u'afflalo',
#  489: u'affordable',
#  490: u'afgha',
#  491: u'afghan',
#  492: u'afghanistan',
#  493: u'afifiabrazak',
#  494: u'afl',
#  495: u'afloat',
#  496: u'afp',
#  497: u'afps',
#  498: u'afptehran',
#  499: u'afraid',
#  500: u'africa',
#  501: u'aftr',
#  502: u'agao',
#  503: u'age',
#  504: u'aged',
#  505: u'ageekk',
#  506: u'agency',
#  507: u'agent',
#  508: u'agents',
#  509: u'aggressive',
#  510: u'agitation',
#  511: u'ago',
#  512: u'agoa',
#  513: u'agree',
#  514: u'agreed',
#  515: u'agreement',
#  516: u'ah',
#  517: u'ahai',
#  518: u'ahead',
#  519: u'ahmad',
#  520: u'ahmad_150',
#  521: u'ahmadramazan',
#  522: u'ahmadrickyfebrian',
#  523: u'ahmed',
#  524: u'ahmmadhasani',
#  525: u'ahramonline',
#  526: u'ahwaz',
#  527: u'ai',
#  528: u'aid',
#  529: u'aidresources',
#  530: u'aihr',
#  531: u'aim',
#  532: u'aims',
#  533: u'ain',
#  534: u'aipac',
#  535: u'air',
#  536: u'aircraft',
#  537: u'airlines',
#  538: u'airmen',
#  539: u'airport',
#  540: u'airspace',
#  541: u'airstrikes',
#  542: u'airtime',
#  543: u'aizanzenzon',
#  544: u'aj100kblog',
#  545: u'aj96263',
#  546: u'ajaco92',
#  547: u'ajam',
#  548: u'ajenews',
#  549: u'ajenglish',
#  550: u'aki017f',
#  551: u'akp',
#  552: u'al',
#  553: u'al_waisman',
#  554: u'alaa',
#  555: u'alam',
#  556: u'alarabiya_eng',
#  557: u'alarm',
#  558: u'alberthalpert',
#  559: u'albi_sidearms',
#  560: u'album',
#  561: u'albums',
#  562: u'alcohol',
#  563: u'aldana_angel',
#  564: u'aldub',
#  565: u'aldubnewjourney',
#  566: u'aleppo',
#  567: u'alert',
#  568: u'alerts',
#  569: u'aleta',
#  570: u'alex',
#  571: u'alexalltimelow',
#  572: u'alexanderlambrt',
#  573: u'alexanderwear',
#  574: u'alexdenmon',
#  575: u'alexisisbestest',
#  576: u'alexyantsevich',
#  577: u'alfapedia',
#  578: u'algemeiner',
#  579: u'algeria',
#  580: u'algorith',
#  581: u'algorithm',
#  582: u'aliamir1342',
#  583: u'alias',
#  584: u'alibi',
#  585: u'alicekeeler',
#  586: u'alien',
#  587: u'aliettedb',
#  588: u'aligned',
#  589: u'aligning',
#  590: u'alingtutan',
#  591: u'alitahmizian',
#  592: u'alitrendeetoad',
#  593: u'alivaez',
#  594: u'allaboutmicrosoft',
#  595: u'allah',
#  596: u'allanimeinforma',
#  597: u'allegations',
#  598: u'allegedly',
#  599: u'allegiance',
#  600: u'allen',
#  601: u'alleywatch',
#  602: u'alliance',
#  603: u'allies',
#  604: u'allisonrocc',
#  605: u'alloush',
#  606: u'allow',
#  607: u'allowed',
#  608: u'ally',
#  609: u'alphabet',
#  610: u'alphabetsuccess',
#  611: u'alright',
#  612: u'alt',
#  613: u'altaf4interfaithunity',
#  614: u'alter',
#  615: u'alteryx',
#  616: u'althedentist',
#  617: u'altman',
#  618: u'altusi313',
#  619: u'alu',
#  620: u'aluminium',
#  621: u'alumni',
#  622: u'alyius_',
#  623: u'amaka_ekwo',
#  624: u'amalsaher',
#  625: u'amanda',
#  626: u'amateur',
#  627: u'amazed',
#  628: u'amazing',
#  629: u'amazon',
#  630: u'amazonecho',
#  631: u'ambassador',
#  632: u'ambassadors',
#  633: u'ambipolar',
#  634: u'ambulance',
#  635: u'amen',
#  636: u'amer_al7shar_1',
#  637: u'america',
#  638: u'american',
#  639: u'americans',
#  640: u'amid',
#  641: u'amir',
#  642: u'amirhekmati',
#  643: u'amitkarp',
#  644: u'amla',
#  645: u'ammon',
#  646: u'amnesty',
#  647: u'amp',
#  648: u'amplify',
#  649: u'amranemm',
#  650: u'amsafavi',
#  651: u'amwriting',
#  652: u'amy_sherel',
#  653: u'amyvanson',
#  654: u'amzn',
#  655: u'analysis',
#  656: u'analyst',
#  657: u'analytics',
#  658: u'analyzd',
#  659: u'analyze',
#  660: u'anchor',
#  661: u'ancient',
#  662: u'andashville',
#  663: u'anderson',
#  664: u'andrearene',
#  665: u'andrew',
#  666: u'andrewatter',
#  667: u'andrewlx',
#  668: u'andrewm54220189',
#  669: u'android',
#  670: u'android_beat',
#  671: u'androidcentral',
#  672: u'androidgames',
#  673: u'andx3a',
#  674: u'andygoh118',
#  675: u'andyholt4tn',
#  676: u'angel',
#  677: u'angela_pascali',
#  678: u'angeles',
#  679: u'anghami',
#  680: u'anglo',
#  681: u'angrily',
#  682: u'angry',
#  683: u'angryrpsavage',
#  684: u'angst',
#  685: u'anikin',
#  686: u'animals',
#  687: u'animations',
#  688: u'ann',
#  689: u'annailuj_sotnas',
#  690: u'anne',
#  691: u'annecutie2016',
#  692: u'annetreasure',
#  693: u'annexations',
#  694: u'announce',
#  695: u'announced',
#  696: u'announcement',
#  697: u'announces',
#  698: u'annoyed',
#  699: u'annrhefn',
#  700: u'annual',
#  701: u'annually',
#  702: u'anonijihad',
#  703: u'answer',
#  704: u'answering',
#  705: u'answers',
#  706: u'antarctic',
#  707: u'antebellum',
#  708: u'antenna',
#  709: u'anthology',
#  710: u'anti',
#  711: u'antifa',
#  712: u'antioxidant',
#  713: u'antique',
#  714: u'ants',
#  715: u'anymore',
#  716: u'anytime',
#  717: u'aol',
#  718: u'ap',
#  719: u'apart',
#  720: u'apartment',
#  721: u'apc',
#  722: u'apdtraffic',
#  723: u'apeterson101',
#  724: u'api',
#  725: u'apis',
#  726: u'apologize',
#  727: u'apology',
#  728: u'app',
#  729: u'apparel',
#  730: u'apparently',
#  731: u'appear',
#  732: u'appeasement',
#  733: u'apple',
#  734: u'applebee',
#  735: u'application',
#  736: u'applications',
#  737: u'applink',
#  738: u'apply',
#  739: u'appreciated',
#  740: u'appreciation',
#  741: u'approach',
#  742: u'appropriate',
#  743: u'approvais',
#  744: u'apps',
#  745: u'appsolute',
#  746: u'appsperience',
#  747: u'appstore',
#  748: u'appzapp',
#  749: u'april',
#  750: u'apropriate',
#  751: u'aqims',
#  752: u'ara',
#  753: u'arab',
#  754: u'arabia',
#  755: u'arabian',
#  756: u'arabic',
#  757: u'arabs',
#  758: u'arabspring',
#  759: u'arabthomness',
#  760: u'arch',
#  761: u'archaeologist',
#  762: u'archaeologists',
#  763: u'archaeology',
#  764: u'archduke',
#  765: u'archie',
#  766: u'archiver',
#  767: u'arctic',
#  768: u'arduino',
#  769: u'area',
#  770: u'areal',
#  771: u'aren',
#  772: u'arena',
#  773: u'argument',
#  774: u'ariana961',
#  775: u'arkadiy',
#  776: u'arm',
#  777: u'armchair',
#  778: u'armed',
#  779: u'armenians',
#  780: u'arming',
#  781: u'armour',
#  782: u'armw501',
#  783: u'army',
#  784: u'arnold',
#  785: u'arrests',
#  786: u'arrival',
#  787: u'arrive',
#  788: u'arroba',
#  789: u'arron',
#  790: u'arruple',
#  791: u'ars',
#  792: u'art',
#  793: u'artefacts',
#  794: u'artfulkiss',
#  795: u'arthurschwartz',
#  796: u'article',
#  797: u'articles',
#  798: u'artificial',
#  799: u'artificialintelligence',
#  800: u'artificially',
#  801: u'artist',
#  802: u'artists',
#  803: u'arutz',
#  804: u'arvindkejriwal',
#  805: u'arzaylea',
#  806: u'asante',
#  807: u'asap',
#  808: u'asawinstanley',
#  809: u'asb',
#  810: u'asd',
#  811: u'asdya6stgashfy1',
#  812: u'asdyastfyhjnby1',
#  813: u'asf',
#  814: u'ashburn',
#  815: u'ashton',
#  816: u'asia',
#  817: u'asian',
#  818: u'asiansfortrump',
#  819: u'aside',
#  820: u'ask',
#  821: u'asked',
#  822: u'asking',
#  823: u'asks',
#  824: u'aspnet',
#  825: u'ass',
#  826: u'assa',
#  827: u'assa2016',
#  828: u'assad',
#  829: u'assassin',
#  830: u'assassination',
#  831: u'assault',
#  832: u'assembles',
#  833: u'assertions',
#  834: u'assignment',
#  835: u'assignments',
#  836: u'assist',
#  837: u'assistant',
#  838: u'assnat',
#  839: u'associated',
#  840: u'assyrians',
#  841: u'astral',
#  842: u'astrophysicists',
#  843: u'astute',
#  844: u'asus',
#  845: u'ata',
#  846: u'ate',
#  847: u'atenafarghadani',
#  848: u'atheism',
#  849: u'atheist',
#  850: u'atkin',
#  851: u'atl',
#  852: u'atlanta',
#  853: u'atlantahawks',
#  854: u'atlanticrecords',
#  855: u'atmos',
#  856: u'atomic',
#  857: u'att',
#  858: u'attach',
#  859: u'attached',
#  860: u'attack',
#  861: u'attacked',
#  862: u'attackers',
#  863: u'attacking',
#  864: u'attacks',
#  865: u'attempt',
#  866: u'attend',
#  867: u'attendant',
#  868: u'attention',
#  869: u'attitude',
#  870: u'attract',
#  871: u'atx',
#  872: u'au',
#  873: u'aucuparia_',
#  874: u'audacity',
#  875: u'audience',
#  876: u'audio',
#  877: u'audiobooks',
#  878: u'audition',
#  879: u'aus',
#  880: u'auspol',
#  881: u'aussie',
#  882: u'austerity',
#  883: u'austin',
#  884: u'austins',
#  885: u'australia',
#  886: u'australian',
#  887: u'ausvotes',
#  888: u'authenticator',
#  889: u'author',
#  890: u'authorella',
#  891: u'authorities',
#  892: u'authority',
#  893: u'authorization',
#  894: u'authors',
#  895: u'authorship',
#  896: u'autistic',
#  897: u'auto',
#  898: u'autocomplete',
#  899: u'autograph',
#  900: u'automatic',
#  901: u'automatically',
#  902: u'automation',
#  903: u'automotive',
#  904: u'automotive_news',
#  905: u'autos',
#  906: u'available',
#  907: u'avatar',
#  908: u'ave',
#  909: u'averofcy',
#  910: u'avgs',
#  911: u'aviles',
#  912: u'aviv',
#  913: u'avoid',
#  914: u'avoidthem',
#  915: u'avon',
#  916: u'avrammeitner',
#  917: u'awaken',
#  918: u'awakens',
#  919: u'award',
#  920: u'awards',
#  921: u'aware',
#  922: u'away',
#  923: u'awe',
#  924: u'aweber321',
#  925: u'awebsitetraffic',
#  926: u'awesome',
#  927: u'aws',
#  928: u'azardaneshgu',
#  929: u'azjaaaaah',
#  930: u'azkar',
#  931: u'azure',
#  932: u'azuread',
#  933: u'azzabi',
#  934: u'b2b',
#  935: u'b2c',
#  936: u'b2community',
#  937: u'b2gether',
#  938: u'b4infeatured',
#  939: u'b_o_necaise',
#  940: u'ba',
#  941: u'baam',
#  942: u'babchenko',
#  943: u'babe',
#  944: u'babes',
#  945: u'baby',
#  946: u'babylonian',
#  947: u'bach',
#  948: u'bachelor',
#  949: u'backed',
#  950: u'backers',
#  951: u'background',
#  952: u'backing',
#  953: u'backlink',
#  954: u'backlinks',
#  955: u'backtracking',
#  956: u'backup',
#  957: u'backyard',
#  958: u'bad',
#  959: u'badaboom',
#  960: u'badass',
#  961: u'badly',
#  962: u'baekfanunionina',
#  963: u'baekhyun',
#  964: u'baeseuldy',
#  965: u'bahareazady',
#  966: u'bahrain',
#  967: u'bakery',
#  968: u'balagan_films',
#  969: u'balan',
#  970: u'balance',
#  971: u'baleighcovey',
#  972: u'balls',
#  973: u'bamboozled',
#  974: u'ban',
#  975: u'band',
#  976: u'bandekhuda',
#  977: u'bandwagon',
#  978: u'banee',
#  979: u'bangalore',
#  980: u'bangladesh',
#  981: u'banjara',
#  982: u'bank',
#  983: u'banker',
#  984: u'banking',
#  985: u'bankrupt',
#  986: u'banner',
#  987: u'banners',
#  988: u'bans',
#  989: u'bar',
#  990: u'barackobama',
#  991: u'baratunde',
#  992: u'bardoon',
#  993: u'bargain',
#  994: u'barneyblues',
#  995: u'baronnissan1',
#  996: u'bars',
#  997: u'bart172_',
#  998: u'bartscharts',
#  999: u'base',
#  ...}

# %%
\

# %% [markdown]
# ### We want to learn which columns are correlated (i.e., likely to come from the same topic).  This is the word distribution.  We can also determine what topics are in each document, the topic distribution.

# %%
# First we convert our word-matrix into gensim's format

corpus = matutils.Sparse2Corpus(documents, documents_columns = False)

# %% [markdown]
# (Check https://radimrehurek.com/gensim/matutils as needed)

# %%
corpus

# %% [markdown]
# (Check https://radimrehurek.com/gensim/models/ldamodel as needed)

# %%
# Then we fit an LDA model

model = models.ldamodel.LdaModel(corpus = corpus, num_topics = 15, id2word = id2word, passes = 10)

# %% [markdown]
# In this model, we need to explicitly specify the number of topic we want the model to uncover.  This is a critical parameter, but there isn't much guidance on how to choose it.  Try to use domain expertise where possible.

# %%
model

# %% [markdown]
# ### Goodness of fit

# %% [markdown]
# Now we need to assess the goodness of fit for our model.  Like other unsupervised learning techniques, our validation techniques are mostly about interpretation.
#
# Use the following questions to guide you:
# - Did we learn reasonable topics?
# - Do the words that make up a topic make sense?
# - Is this topic helpful towards our goal?

# %%
model.print_topics()
# Out:
# [(14,
#   u'0.078*just + 0.030*google + 0.023*afghanistan + 0.019*gen + 0.017*lawyer + 0.017*pinned + 0.016*rt + 0.012*android + 0.011*androidgames + 0.011*gameinsight'),
#  (6,
#   u'0.049*microsoft + 0.036*google + 0.019*cancer + 0.018*reason + 0.015*windows + 0.014*uk + 0.012*best + 0.012*years + 0.011*rt + 0.010*10'),
#  (8,
#   u'0.046*google + 0.041*today + 0.037*play + 0.027*app + 0.025*store + 0.024*rt + 0.024*darksummoner + 0.023*libya + 0.022*king + 0.022*news'),
#  (5,
#   u'0.069*google + 0.026*good + 0.018*rt + 0.018*deal + 0.015*nexus + 0.015*start + 0.013*data + 0.013*ve + 0.012*youtube + 0.012*solar'),
#  (10,
#   u'0.024*rt + 0.023*google + 0.017*bid + 0.012*ukraine + 0.012*mtp + 0.011*fns + 0.010*usa + 0.010*android + 0.010*palestine + 0.008*israel'),
#  (1,
#   u'0.069*iran + 0.066*rt + 0.065*saudi + 0.034*arabia + 0.020*syria + 0.019*ties + 0.014*war + 0.014*amp + 0.011*saudiarabia + 0.010*world'),
#  (4,
#   u'0.041*israel + 0.024*rt + 0.019*amp + 0.012*gt + 0.011*state + 0.010*google + 0.010*force + 0.009*iranian + 0.008*egypt + 0.008*states'),
#  (0,
#   u'0.038*verizon + 0.034*rt + 0.026*google + 0.025*apple + 0.022*iphone + 0.017*search + 0.011*amp + 0.009*live + 0.009*attack + 0.009*nba'),
#  (12,
#   u'0.030*rt + 0.019*russia + 0.018*learn + 0.018*lost + 0.017*download + 0.016*marybeforejane + 0.015*code + 0.015*30 + 0.015*rewards + 0.014*whaff'),
#  (7,
#   u'0.038*rt + 0.019*amp + 0.016*weed + 0.015*killed + 0.009*house + 0.009*ads + 0.009*said + 0.009*stocks + 0.008*injured + 0.008*50')]

# %% [markdown]
# Some topics will be clearer than others.  The following topics represent clear concepts:
# - Cooking and Recipes: 0.009 \* cup + 0.009 \* recipe + 0.007 \* make + 0.007 \* food + 0.006 \* sugar
# - Cooking and recipes: 0.013 \* butter + 0.010 \* baking + 0.010 \* dough + 0.009 \* cup + 0.009 \* sugar
# - Fashion and Style: 0.013 \* fashion + 0.006 \* like + 0.006 \* dress + 0.005 \* style

# %% [markdown]
# ## Word2Vec with Gensim

# %%
# Setup the body text
sentences = df.content.map(lambda content: content.split())

# %%
sentences
# Out:
# 0       [new, photos, of, spacex, booster, show, sooty...
# 1       [rt, @purelovebeast:, -เช็ครายละเอียด-, 27th, ...
# 2                                                      []
# 3                       [@vigigu, google, it, :), simple]
# 4                                       [nerd, ass, girl]
#                               ...
# 4888    [tesla, rival, may, be, producing, a, batmobil...
# 4889    [mercedes-benz, plans, four, new, electric, #t...
# 4890    [rt, @hblodget:, new, tesla, competitor, is, l...
# 4891    [spacex, rocket, in, great, shape, after, hist...
# 4892    [new, photos, of, spacex, booster, show, sooty...
# Name: content, dtype: object

# %%
model = models.Word2Vec(sentences, size = 100, window = 5, min_count = 5, workers = 4)
# Out:
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay

# %% [markdown]
# `Word2Vec` has many arguments:
# - `size` represents how many concepts or topics we should use
# - `window` represents how many words surrounding a sentence we should use as our original feature
# - `min_count` is the number of times that context or word must appear
# - `workers` is the number of CPU cores to use to speed up model training
#
# (Check http://radimrehurek.com/gensim/models/word2vec as needed)

# %%
model

# %% [markdown]
# ### Most similar words

# %% [markdown]
# The model has a `most_similar` function that helps find the words most similar to the one you queried.  This will return words that are most often used in the same context.

# %%
model.most_similar(positive = ['syria'])
# Out:
# [('over', 0.9998472929000854),
#  ('after', 0.999840497970581),
#  ('who', 0.999830424785614),
#  ('people', 0.9998241662979126),
#  ('2016', 0.9998232126235962),
#  ('#news', 0.9998089671134949),
#  ('has', 0.9998032450675964),
#  ('via', 0.9998021125793457),
#  ("i'm", 0.9997999668121338),
#  ('an', 0.9997988939285278)]

# %%
vectorizer.get_feature_names()
# Out:
# [u'00',
#  u'000',
#  u'00am',
#  u'01',
#  u'0161',
#  u'01c',
#  u'02',
#  u'034',
#  u'039',
#  u'04',
#  u'0430mayi',
#  u'0502',
#  u'0574',
#  u'06',
#  u'07',
#  u'10',
#  u'100',
#  u'1000',
#  u'100000',
#  u'1000s',
#  u'100bn',
#  u'100d',
#  u'100esquses',
#  u'100mp',
#  u'100s',
#  u'1010lt',
#  u'1028',
#  u'1091',
#  u'10pm',
#  u'11',
#  u'11000',
#  u'110k',
#  u'111',
#  u'1159pm',
#  u'1159pmpactm',
#  u'118',
#  u'11sixedits',
#  u'12',
#  u'1213',
#  u'123000',
#  u'125',
#  u'127',
#  u'1279',
#  u'1282048b33ba483',
#  u'12me',
#  u'13',
#  u'13000',
#  u'131',
#  u'1311',
#  u'132k',
#  u'14',
#  u'1439',
#  u'145',
#  u'1451886241',
#  u'148',
#  u'14gb',
#  u'14th',
#  u'15',
#  u'150',
#  u'1540',
#  u'1588days',
#  u'158b78679ddc4b6',
#  u'15gb',
#  u'16',
#  u'16000',
#  u'16gb',
#  u'16mile',
#  u'17',
#  u'1723091184',
#  u'1763210325',
#  u'1783',
#  u'17carat',
#  u'18',
#  u'1800',
#  u'1810',
#  u'1811',
#  u'1862185791',
#  u'1865846254',
#  u'19',
#  u'1942',
#  u'1957_tintin_',
#  u'1970s',
#  u'1977755529',
#  u'1979',
#  u'1980s',
#  u'1989',
#  u'1992',
#  u'1998',
#  u'1999',
#  u'19th',
#  u'1d',
#  u'1evilidiot',
#  u'1gb',
#  u'1jihn',
#  u'1linewed',
#  u'1novel',
#  u'1st',
#  u'20',
#  u'200',
#  u'2000',
#  u'2002',
#  u'2003',
#  u'2005',
#  u'2007',
#  u'2008',
#  u'2009',
#  u'2009y',
#  u'200d',
#  u'200m',
#  u'2010',
#  u'2011',
#  u'2012',
#  u'2013',
#  u'2014',
#  u'20140618',
#  u'2015',
#  u'2016',
#  u'2016tips',
#  u'2017',
#  u'2020',
#  u'2036',
#  u'204',
#  u'2046',
#  u'2052',
#  u'2053',
#  u'2054',
#  u'2057',
#  u'205a',
#  u'2060',
#  u'2062',
#  u'2086',
#  u'20d',
#  u'21',
#  u'2100mah',
#  u'2106',
#  u'21st',
#  u'22',
#  u'221',
#  u'2248048877',
#  u'225',
#  u'23',
#  u'2343598528',
#  u'236',
#  u'238',
#  u'24',
#  u'247',
#  u'25',
#  u'250',
#  u'25000',
#  u'250gb',
#  u'2512584150',
#  u'254',
#  u'2592041653',
#  u'25h',
#  u'25sm',
#  u'26',
#  u'265',
#  u'2699',
#  u'27',
#  u'2769',
#  u'27th',
#  u'28',
#  u'2880633443',
#  u'29',
#  u'2avag3',
#  u'2establish',
#  u'2gb',
#  u'2kjsofea',
#  u'2kyuhyun',
#  u'2mgovercsquared',
#  u'2military',
#  u'2nd',
#  u'2pac',
#  u'2pm',
#  u'2pmphilippines',
#  u'30',
#  u'3000',
#  u'302',
#  u'303',
#  u'3079',
#  u'30seclovelive',
#  u'310000',
#  u'31day2aclutterfreelife',
#  u'32',
#  u'320',
#  u'32gb',
#  u'32k',
#  u'33',
#  u'333',
#  u'34',
#  u'341',
#  u'35',
#  u'350',
#  u'352',
#  u'36',
#  u'360',
#  u'3636',
#  u'38',
#  u'39',
#  u'3d',
#  u'3ds',
#  u'3g',
#  u'3rd',
#  u'3unit',
#  u'40',
#  u'400',
#  u'40z',
#  u'41',
#  u'418000',
#  u'41810',
#  u'42',
#  u'420',
#  u'4255x2845px',
#  u'432',
#  u'44',
#  u'45',
#  u'46',
#  u'4623',
#  u'465mph',
#  u'47',
#  u'48',
#  u'4895',
#  u'499',
#  u'49ers',
#  u'4freedominiran',
#  u'4g',
#  u'4nn',
#  u'4s',
#  u'4th',
#  u'50',
#  u'500',
#  u'50000',
#  u'504bayou',
#  u'50d',
#  u'50k',
#  u'50mbit',
#  u'50vs50',
#  u'51',
#  u'5244',
#  u'541',
#  u'543',
#  u'55',
#  u'57',
#  u'58',
#  u'580m',
#  u'587',
#  u'59',
#  u'5950',
#  u'59am',
#  u'5c',
#  u'5eva',
#  u'5k',
#  u'5m',
#  u'5pm',
#  u'5s',
#  u'5x',
#  u'60',
#  u'6021',
#  u'630',
#  u'64',
#  u'641',
#  u'642',
#  u'64gb',
#  u'65',
#  u'6584lb',
#  u'66',
#  u'667',
#  u'69',
#  u'6p',
#  u'6pm',
#  u'6s',
#  u'70',
#  u'700',
#  u'70mm',
#  u'70s',
#  u'7111',
#  u'72',
#  u'7268',
#  u'73',
#  u'731',
#  u'7482',
#  u'75',
#  u'76',
#  u'77',
#  u'785',
#  u'79',
#  u'7910',
#  u'7pm',
#  u'7th',
#  u'80',
#  u'800',
#  u'8000',
#  u'8093',
#  u'80s',
#  u'80smetal',
#  u'82',
#  u'8217',
#  u'8230',
#  u'825',
#  u'84',
#  u'8439',
#  u'85',
#  u'850',
#  u'856mo_thiun',
#  u'867',
#  u'87',
#  u'88',
#  u'89',
#  u'8g',
#  u'8gb',
#  u'8k',
#  u'8x10',
#  u'90',
#  u'90s',
#  u'91sticker',
#  u'92',
#  u'92650',
#  u'928',
#  u'95',
#  u'950',
#  u'9568',
#  u'96',
#  u'9650',
#  u'97',
#  u'98',
#  u'981',
#  u'99',
#  u'9912980188',
#  u'9926170436',
#  u'9991',
#  u'9gag',
#  u'_17studio',
#  u'_____',
#  u'_andreaa1417',
#  u'_bruno_rod_',
#  u'_lightskingoddd',
#  u'_omgalexa',
#  u'_queenlioness_',
#  u'_queenselina_',
#  u'_rachaelmcclung',
#  u'_real_',
#  u'_sem',
#  u'_shockieee',
#  u'_silentbent_',
#  u'_snats',
#  u'_spraytan',
#  u'_valeria_anahi',
#  u'_violet218',
#  u'_zach_c',
#  u'a33',
#  u'a7rii',
#  u'a_manaf999',
#  u'aa',
#  u'aaa',
#  u'aaronkleinshow',
#  u'abashed',
#  u'abasnadimy',
#  u'abbey',
#  u'abbswinston',
#  u'abc',
#  u'abdulah_alasiri',
#  u'abdulahalshamri',
#  u'abeer3f',
#  u'abel',
#  u'abidifactor',
#  u'abigailbellair',
#  u'able',
#  u'abo',
#  u'abogomolov',
#  u'abroad',
#  u'absence',
#  u'absolutely',
#  u'absolutley',
#  u'absolutly',
#  u'abt',
#  u'abu',
#  u'abunass3r',
#  u'abuse',
#  u'abuses',
#  u'abusing',
#  u'abusive',
#  u'abutalal1793',
#  u'ac',
#  u'academy',
#  u'acaiabrese',
#  u'accelerates',
#  u'access',
#  u'accessories',
#  u'accident',
#  u'accidentally',
#  u'accidents',
#  u'accomplished',
#  u'accomplishments',
#  u'according',
#  u'account',
#  u'accounts',
#  u'accurate',
#  u'accuse',
#  u'accuses',
#  u'acebandage85',
#  u'achievement',
#  u'achieving',
#  u'acid',
#  u'acknowledges',
#  u'acn',
#  u'acquire',
#  u'acquired',
#  u'acquires',
#  u'acrylics',
#  u'act',
#  u'acting',
#  u'action',
#  u'actions',
#  u'active',
#  u'activist',
#  u'activists',
#  u'activities',
#  u'actor',
#  u'actor_jayamravi',
#  u'actual',
#  u'actualconversation',
#  u'actually',
#  u'ad',
#  u'adam',
#  u'adampeterssst',
#  u'adams',
#  u'adcenter',
#  u'add',
#  u'added',
#  u'addi',
#  u'addicted',
#  u'addictive',
#  u'adding',
#  u'additional',
#  u'address',
#  u'addresses',
#  u'addressing',
#  u'adds',
#  u'adelaideseosa',
#  u'adelaljubeir',
#  u'aden',
#  u'adjustments',
#  u'adl_national',
#  u'admin',
#  u'admits',
#  u'adnansixer',
#  u'adobeindex',
#  u'adopt',
#  u'adoption',
#  u'adrenaline351',
#  u'adrian',
#  u'adrianpeterson',
#  u'adrxano',
#  u'ads',
#  u'adsense',
#  u'adsit',
#  u'adtech',
#  u'adult_goth',
#  u'adults',
#  u'advance',
#  u'advanced',
#  u'advances',
#  u'adventure',
#  u'advertise',
#  u'advertising',
#  u'advice',
#  u'advised',
#  u'adviser',
#  u'advisor',
#  u'advocacy',
#  u'advocates',
#  u'advrosen',
#  u'adweek',
#  u'adwords',
#  u'adzebill',
#  u'aea2016',
#  u'aerial',
#  u'aesthetichalsey',
#  u'aethra',
#  u'af',
#  u'afalli',
#  u'afc',
#  u'affair',
#  u'affairs',
#  u'affected',
#  u'affects',
#  u'affiliate',
#  u'affixpics',
#  u'afflalo',
#  u'affordable',
#  u'afgha',
#  u'afghan',
#  u'afghanistan',
#  u'afifiabrazak',
#  u'afl',
#  u'afloat',
#  u'afp',
#  u'afps',
#  u'afptehran',
#  u'afraid',
#  u'africa',
#  u'aftr',
#  u'agao',
#  u'age',
#  u'aged',
#  u'ageekk',
#  u'agency',
#  u'agent',
#  u'agents',
#  u'aggressive',
#  u'agitation',
#  u'ago',
#  u'agoa',
#  u'agree',
#  u'agreed',
#  u'agreement',
#  u'ah',
#  u'ahai',
#  u'ahead',
#  u'ahmad',
#  u'ahmad_150',
#  u'ahmadramazan',
#  u'ahmadrickyfebrian',
#  u'ahmed',
#  u'ahmmadhasani',
#  u'ahramonline',
#  u'ahwaz',
#  u'ai',
#  u'aid',
#  u'aidresources',
#  u'aihr',
#  u'aim',
#  u'aims',
#  u'ain',
#  u'aipac',
#  u'air',
#  u'aircraft',
#  u'airlines',
#  u'airmen',
#  u'airport',
#  u'airspace',
#  u'airstrikes',
#  u'airtime',
#  u'aizanzenzon',
#  u'aj100kblog',
#  u'aj96263',
#  u'ajaco92',
#  u'ajam',
#  u'ajenews',
#  u'ajenglish',
#  u'aki017f',
#  u'akp',
#  u'al',
#  u'al_waisman',
#  u'alaa',
#  u'alam',
#  u'alarabiya_eng',
#  u'alarm',
#  u'alberthalpert',
#  u'albi_sidearms',
#  u'album',
#  u'albums',
#  u'alcohol',
#  u'aldana_angel',
#  u'aldub',
#  u'aldubnewjourney',
#  u'aleppo',
#  u'alert',
#  u'alerts',
#  u'aleta',
#  u'alex',
#  u'alexalltimelow',
#  u'alexanderlambrt',
#  u'alexanderwear',
#  u'alexdenmon',
#  u'alexisisbestest',
#  u'alexyantsevich',
#  u'alfapedia',
#  u'algemeiner',
#  u'algeria',
#  u'algorith',
#  u'algorithm',
#  u'aliamir1342',
#  u'alias',
#  u'alibi',
#  u'alicekeeler',
#  u'alien',
#  u'aliettedb',
#  u'aligned',
#  u'aligning',
#  u'alingtutan',
#  u'alitahmizian',
#  u'alitrendeetoad',
#  u'alivaez',
#  u'allaboutmicrosoft',
#  u'allah',
#  u'allanimeinforma',
#  u'allegations',
#  u'allegedly',
#  u'allegiance',
#  u'allen',
#  u'alleywatch',
#  u'alliance',
#  u'allies',
#  u'allisonrocc',
#  u'alloush',
#  u'allow',
#  u'allowed',
#  u'ally',
#  u'alphabet',
#  u'alphabetsuccess',
#  u'alright',
#  u'alt',
#  u'altaf4interfaithunity',
#  u'alter',
#  u'alteryx',
#  u'althedentist',
#  u'altman',
#  u'altusi313',
#  u'alu',
#  u'aluminium',
#  u'alumni',
#  u'alyius_',
#  u'amaka_ekwo',
#  u'amalsaher',
#  u'amanda',
#  u'amateur',
#  u'amazed',
#  u'amazing',
#  u'amazon',
#  u'amazonecho',
#  u'ambassador',
#  u'ambassadors',
#  u'ambipolar',
#  u'ambulance',
#  u'amen',
#  u'amer_al7shar_1',
#  u'america',
#  u'american',
#  u'americans',
#  u'amid',
#  u'amir',
#  u'amirhekmati',
#  u'amitkarp',
#  u'amla',
#  u'ammon',
#  u'amnesty',
#  u'amp',
#  u'amplify',
#  u'amranemm',
#  u'amsafavi',
#  u'amwriting',
#  u'amy_sherel',
#  u'amyvanson',
#  u'amzn',
#  u'analysis',
#  u'analyst',
#  u'analytics',
#  u'analyzd',
#  u'analyze',
#  u'anchor',
#  u'ancient',
#  u'andashville',
#  u'anderson',
#  u'andrearene',
#  u'andrew',
#  u'andrewatter',
#  u'andrewlx',
#  u'andrewm54220189',
#  u'android',
#  u'android_beat',
#  u'androidcentral',
#  u'androidgames',
#  u'andx3a',
#  u'andygoh118',
#  u'andyholt4tn',
#  u'angel',
#  u'angela_pascali',
#  u'angeles',
#  u'anghami',
#  u'anglo',
#  u'angrily',
#  u'angry',
#  u'angryrpsavage',
#  u'angst',
#  u'anikin',
#  u'animals',
#  u'animations',
#  u'ann',
#  u'annailuj_sotnas',
#  u'anne',
#  u'annecutie2016',
#  u'annetreasure',
#  u'annexations',
#  u'announce',
#  u'announced',
#  u'announcement',
#  u'announces',
#  u'annoyed',
#  u'annrhefn',
#  u'annual',
#  u'annually',
#  u'anonijihad',
#  u'answer',
#  u'answering',
#  u'answers',
#  u'antarctic',
#  u'antebellum',
#  u'antenna',
#  u'anthology',
#  u'anti',
#  u'antifa',
#  u'antioxidant',
#  u'antique',
#  u'ants',
#  u'anymore',
#  u'anytime',
#  u'aol',
#  u'ap',
#  u'apart',
#  u'apartment',
#  u'apc',
#  u'apdtraffic',
#  u'apeterson101',
#  u'api',
#  u'apis',
#  u'apologize',
#  u'apology',
#  u'app',
#  u'apparel',
#  u'apparently',
#  u'appear',
#  u'appeasement',
#  u'apple',
#  u'applebee',
#  u'application',
#  u'applications',
#  u'applink',
#  u'apply',
#  u'appreciated',
#  u'appreciation',
#  u'approach',
#  u'appropriate',
#  u'approvais',
#  u'apps',
#  u'appsolute',
#  u'appsperience',
#  u'appstore',
#  u'appzapp',
#  u'april',
#  u'apropriate',
#  u'aqims',
#  u'ara',
#  u'arab',
#  u'arabia',
#  u'arabian',
#  u'arabic',
#  u'arabs',
#  u'arabspring',
#  u'arabthomness',
#  u'arch',
#  u'archaeologist',
#  u'archaeologists',
#  u'archaeology',
#  u'archduke',
#  u'archie',
#  u'archiver',
#  u'arctic',
#  u'arduino',
#  u'area',
#  u'areal',
#  u'aren',
#  u'arena',
#  u'argument',
#  u'ariana961',
#  u'arkadiy',
#  u'arm',
#  u'armchair',
#  u'armed',
#  u'armenians',
#  u'arming',
#  u'armour',
#  u'armw501',
#  u'army',
#  u'arnold',
#  u'arrests',
#  u'arrival',
#  u'arrive',
#  u'arroba',
#  u'arron',
#  u'arruple',
#  u'ars',
#  u'art',
#  u'artefacts',
#  u'artfulkiss',
#  u'arthurschwartz',
#  u'article',
#  u'articles',
#  u'artificial',
#  u'artificialintelligence',
#  u'artificially',
#  u'artist',
#  u'artists',
#  u'arutz',
#  u'arvindkejriwal',
#  u'arzaylea',
#  u'asante',
#  u'asap',
#  u'asawinstanley',
#  u'asb',
#  u'asd',
#  u'asdya6stgashfy1',
#  u'asdyastfyhjnby1',
#  u'asf',
#  u'ashburn',
#  u'ashton',
#  u'asia',
#  u'asian',
#  u'asiansfortrump',
#  u'aside',
#  u'ask',
#  u'asked',
#  u'asking',
#  u'asks',
#  u'aspnet',
#  u'ass',
#  u'assa',
#  u'assa2016',
#  u'assad',
#  u'assassin',
#  u'assassination',
#  u'assault',
#  u'assembles',
#  u'assertions',
#  u'assignment',
#  u'assignments',
#  u'assist',
#  u'assistant',
#  u'assnat',
#  u'associated',
#  u'assyrians',
#  u'astral',
#  u'astrophysicists',
#  u'astute',
#  u'asus',
#  u'ata',
#  u'ate',
#  u'atenafarghadani',
#  u'atheism',
#  u'atheist',
#  u'atkin',
#  u'atl',
#  u'atlanta',
#  u'atlantahawks',
#  u'atlanticrecords',
#  u'atmos',
#  u'atomic',
#  u'att',
#  u'attach',
#  u'attached',
#  u'attack',
#  u'attacked',
#  u'attackers',
#  u'attacking',
#  u'attacks',
#  u'attempt',
#  u'attend',
#  u'attendant',
#  u'attention',
#  u'attitude',
#  u'attract',
#  u'atx',
#  u'au',
#  u'aucuparia_',
#  u'audacity',
#  u'audience',
#  u'audio',
#  u'audiobooks',
#  u'audition',
#  u'aus',
#  u'auspol',
#  u'aussie',
#  u'austerity',
#  u'austin',
#  u'austins',
#  u'australia',
#  u'australian',
#  u'ausvotes',
#  u'authenticator',
#  u'author',
#  u'authorella',
#  u'authorities',
#  u'authority',
#  u'authorization',
#  u'authors',
#  u'authorship',
#  u'autistic',
#  u'auto',
#  u'autocomplete',
#  u'autograph',
#  u'automatic',
#  u'automatically',
#  u'automation',
#  u'automotive',
#  u'automotive_news',
#  u'autos',
#  u'available',
#  u'avatar',
#  u'ave',
#  u'averofcy',
#  u'avgs',
#  u'aviles',
#  u'aviv',
#  u'avoid',
#  u'avoidthem',
#  u'avon',
#  u'avrammeitner',
#  u'awaken',
#  u'awakens',
#  u'award',
#  u'awards',
#  u'aware',
#  u'away',
#  u'awe',
#  u'aweber321',
#  u'awebsitetraffic',
#  u'awesome',
#  u'aws',
#  u'azardaneshgu',
#  u'azjaaaaah',
#  u'azkar',
#  u'azure',
#  u'azuread',
#  u'azzabi',
#  u'b2b',
#  u'b2c',
#  u'b2community',
#  u'b2gether',
#  u'b4infeatured',
#  u'b_o_necaise',
#  u'ba',
#  u'baam',
#  u'babchenko',
#  u'babe',
#  u'babes',
#  u'baby',
#  u'babylonian',
#  u'bach',
#  u'bachelor',
#  u'backed',
#  u'backers',
#  u'background',
#  u'backing',
#  u'backlink',
#  u'backlinks',
#  u'backtracking',
#  u'backup',
#  u'backyard',
#  u'bad',
#  u'badaboom',
#  u'badass',
#  u'badly',
#  u'baekfanunionina',
#  u'baekhyun',
#  u'baeseuldy',
#  u'bahareazady',
#  u'bahrain',
#  u'bakery',
#  u'balagan_films',
#  u'balan',
#  u'balance',
#  u'baleighcovey',
#  u'balls',
#  u'bamboozled',
#  u'ban',
#  u'band',
#  u'bandekhuda',
#  u'bandwagon',
#  u'banee',
#  u'bangalore',
#  u'bangladesh',
#  u'banjara',
#  u'bank',
#  u'banker',
#  u'banking',
#  u'bankrupt',
#  u'banner',
#  u'banners',
#  u'bans',
#  u'bar',
#  u'barackobama',
#  u'baratunde',
#  u'bardoon',
#  u'bargain',
#  u'barneyblues',
#  u'baronnissan1',
#  u'bars',
#  u'bart172_',
#  u'bartscharts',
#  u'base',
#  ...]

# %%
sentences
# Out:
# 0       [new, photos, of, spacex, booster, show, sooty...
# 1       [rt, @purelovebeast:, -เช็ครายละเอียด-, 27th, ...
# 2                                                      []
# 3                       [@vigigu, google, it, :), simple]
# 4                                       [nerd, ass, girl]
#                               ...
# 4888    [tesla, rival, may, be, producing, a, batmobil...
# 4889    [mercedes-benz, plans, four, new, electric, #t...
# 4890    [rt, @hblodget:, new, tesla, competitor, is, l...
# 4891    [spacex, rocket, in, great, shape, after, hist...
# 4892    [new, photos, of, spacex, booster, show, sooty...
# Name: content, dtype: object

# %%
sentences = list(map(lambda sentence: list(filter(lambda word: word in vectorizer.get_feature_names(), sentence)), sentences))
# Out:
# C:\Anaconda3\envs\py27\lib\site-packages\ipykernel\__main__.py:1: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   if __name__ == '__main__':

# %%
sentences
# Out:
# [['new', 'photos', 'spacex', 'booster', 'sooty', 'undamaged', 'rocket'],
#  ['rt', '27th', 'birthday', 'special', 'goods', '3d', 'yoseop', 'usb'],
#  [],
#  ['google', 'simple'],
#  ['nerd', 'ass', 'girl'],
#  ['leadcorp', 'media'],
#  ['rt', 'chiemoney', 'use', 'google', 'learn'],
#  ['morning',
#   'bro',
#   'new',
#   'video',
#   'need',
#   'yr',
#   'help',
#   'im',
#   'talented',
#   'bt',
#   'lack',
#   'manager',
#   'bro'],
#  ['google', 'play', 'gift', 'card', 'code'],
#  ['claim', 'google', 'play', 'gift', 'card'],
#  ['devs', 'sport', 'come'],
#  [],
#  [],
#  ['king', 'dark', 'summon', 'app', 'google'],
#  ['king', 'dark', 'summon', 'app', 'google'],
#  ['read', 'published', 'article', 'russell', 'simmons', 'wrote', 'google'],
#  ['entered', 'win', 'google', 'nexus', '6p'],
#  ['saw', 'online', 'like', 'google', 'reviews'],
#  ['rt', 'entered', 'win', 'google', 'nexus', '6p'],
#  ['yayyyyy', 'thanks', 'follow'],
#  ['love', 'google', 'plus', 'page'],
#  ['google', 'read', 'ton', 'articles', 'just', 'searched', 'youtube', 'shit'],
#  ['week', 'power'],
#  ['rt', 'apple', 'amazon', 'google', 'microsoft'],
#  ['google'],
#  ['rt', 'support', 'single', 'feat'],
#  ['checkout'],
#  ['rt', 'nerd', 'ass', 'girl'],
#  ['playing', 'singing', 'check'],
#  ['wanted', 'google', 'small', 'business'],
#  ['check', 'worry', 'losing', 'device', '10', 'gb', 'free', 'backup'],
#  ['android', 'apps', 'revealed', 'hidden', 'google', 'play', 'store', 'link'],
#  ['rt', 'th8', 'come', 'join'],
#  ['increase', 'blog', 'traffic', 'google', 'plus'],
#  [],
#  ['europe', 'produce', 'facebook', 'google', 'healthcare'],
#  ['daily'],
#  [],
#  ['europe', 'produce', 'facebook', 'google', 'healthcare'],
#  ['daily'],
#  ['new',
#   'google',
#   'knowledge',
#   'graph',
#   'optimization',
#   'strategies',
#   'new',
#   'year',
#   'infographic',
#   'designers'],
#  ['spend',
#   'entire',
#   'time',
#   'driving',
#   'trying',
#   'beat',
#   'original',
#   'arrival',
#   'time',
#   'estimate',
#   'google'],
#  ['font', 'mecka'],
#  ['failed', 'tell', 'crystals', 'inside'],
#  ['rt', 'meaning'],
#  [],
#  [],
#  ['time'],
#  ['google'],
#  ['rt', 'th8', 'come', 'join'],
#  ['time', 'commented', 'google', 'basically', 'old', 'guy', 'complimenting'],
#  ['rt', 'sleep', '10pm', 'decent', 'hours'],
#  ['stays', 'google', 'different', 'food', 'recipes'],
#  ['rt', 'use', 'apis', 'gunjanraik'],
#  ['rt',
#   'android',
#   'application',
#   'related',
#   'google',
#   'maps',
#   'need',
#   'update',
#   'android'],
#  ['mini', 'just', 'went', 'th9', 'fun', 'event', 'th8s'],
#  ['ancient', 'massive', 'face', 'shape', 'remain'],
#  ['hector',
#   'softly',
#   'tilted',
#   'head',
#   'stuart',
#   'confused',
#   'sort',
#   'possibly',
#   'know'],
#  ['good', 'domain', 'virginia', 'trending'],
#  ['man', 'talk', 'cubs', 'won', 'year'],
#  ['google', 'knowledge', 'graph', 'optimization', 'strategies', 'new', 'year'],
#  ['rt', 'open', 'sources', 'artificial', 'servers'],
#  [],
#  ['earn',
#   'free',
#   'google',
#   'play',
#   'giftcards',
#   'fresh',
#   'published',
#   'website'],
#  ['rt',
#   'bunnymiilk',
#   '30',
#   'seconds',
#   'love',
#   '5k',
#   'followers',
#   'giveaway',
#   'play',
#   'gift'],
#  ['rt', 'google', 'taking', 'uber', '2016'],
#  ['google',
#   'minecraft',
#   'image',
#   'popped',
#   'real',
#   'geographical',
#   'scenic',
#   'spot'],
#  ['greatest', 'changing', 'google'],
#  ['state'],
#  ['google', 'wolf', 'hybrid', 'future', 'dog'],
#  ['europe', 'produce', 'facebook', 'google', 'healthcare'],
#  ['unlocked', 'new', 'area'],
#  ['latest', 'free', 'android', 'wallpaper', 'shows', 'useful', 'phone'],
#  ['reached', 'level', 'earned'],
#  ['make',
#   'sure',
#   'siwe',
#   'ishkeeping',
#   'xsers',
#   'mn',
#   'thxir',
#   'preferred',
#   'fkyourmwebsite',
#   'tceir',
#   'entule',
#   'webmcstervkx'],
#  ['rt', 'mini', 'just', 'went', 'th9', 'fun', 'event', 'th8s'],
#  ['2013',
#   'champ',
#   'marshawn',
#   'lynch',
#   'touchdown',
#   'run',
#   'seattle',
#   'seahawks',
#   '8x10',
#   'photo'],
#  ['completely', 'agree', 'killing', 'google', 'case', 'haha'],
#  ['whats', 'ask', 'google'],
#  ['rt', 'alt', 'alt', 'alt', 'alt'],
#  ['rt', 'tell', 'zuck', 'planning', 'google'],
#  ['got', 'google', 'docs', 'open'],
#  ['rt', 'apple', 'amazon', 'google'],
#  ['copy', 'paste', 'tweet'],
#  ['instructions', 'just', 'saved'],
#  ['rt',
#   'pathankot',
#   'youth',
#   'congress',
#   'members',
#   'burn',
#   'sharifs',
#   'effigy',
#   'bhopal'],
#  [],
#  ['revamped', 'better', 'got7', 'primer', 'share', 'boys', 'world'],
#  ['entered', 'win', 'google', 'nexus', '6p'],
#  ['new', 'mobile', 'apps', 'gods', 'cut', 'gun', 'kitwall'],
#  [],
#  ['googleexpertuk', 'supports', 'swedish', 'chef', 'muppetsstudio'],
#  ['eco', '100', 'wk', '10', 'chapter', '18', 'homework'],
#  ['look', 'militia', 'second', 'definition'],
#  ['google', 'terms', 'matter', 'bad', 'want'],
#  ['rt', 'bunnymiilk', '30', 'seconds', 'love', '5k', 'followers', 'giveaway'],
#  ['oh', 'thank', 'god', 'google', 'translate', 'wrong'],
#  ['rt', 'support', 'fight'],
#  ['google', 'maps'],
#  ['google', 'say', 'means'],
#  ['rights', 'sign', 'messes', 'google', 'awakens', 'imax', 'link', 'send'],
#  ['rt', 'bts', '2nd', 'muster', 'slogan', 'visual', 'shock'],
#  ['rt', 'open', 'sources', 'artificial', 'servers'],
#  [],
#  ['rt', 'infuriating', 'im', 'using', 'work', 'home'],
#  ['ford', 'adds', 'apple', 'carplay', 'android', 'auto', 'sync'],
#  ['best', 'colour', 'zodiac', 'sign', 'year', '2016'],
#  [],
#  ['hi', 'bro', 'need', 'help', 'new', 'manage', 'bro'],
#  ['try', 'twitgrow', 'real', 'retweets', 'google'],
#  ['rt', 'person', 'misses', 'deadline'],
#  ['greatest', 'changing', 'google'],
#  ['rt', 'jimin', '2016', 'stock', 'sale', 'miningful', 'moment'],
#  ['communicate', 'stupid', 'affiliate', '10'],
#  ['playing', 'apple', 'google'],
#  ['google', 'search', 'wanna', 'disappointed'],
#  ['just',
#   'like',
#   'new',
#   'college',
#   'students',
#   'risk',
#   'freshman',
#   'google',
#   'employees',
#   'joke',
#   'google',
#   '15',
#   'snaks'],
#  ['af'],
#  ['spare',
#   'mark',
#   'respects',
#   'google',
#   'android',
#   'scum',
#   'april',
#   'au',
#   'pair',
#   'skacv'],
#  ['google',
#   'used',
#   'surgeons',
#   'perform',
#   'heart',
#   'surgery',
#   'saves',
#   'life'],
#  ['rt', 'spending', 'money', 'saves', 'time', 'earns', 'work', 'home'],
#  ['house',
#   'selling',
#   'dirt',
#   'google',
#   'maps',
#   'picture',
#   'explains',
#   'exactly'],
#  ['google', 'chill'],
#  ['rt', 'got7', 'connect', 'bracelet'],
#  [],
#  [],
#  ['women', 'rise', 'hp', 'panchayat', 'politics'],
#  ['police',
#   'condemn',
#   'facebook',
#   'comments',
#   'mount',
#   'maunganui',
#   'new',
#   'eve',
#   'page'],
#  ['wondering', 'food', 'healthier', 'google', 'tool'],
#  ['rt', 'iran', 'blames', 'britain', 'nimr', 'execution'],
#  ['replied'],
#  [],
#  ['gunakan', 'lah', 'google', 'lol', 'xd'],
#  ['run', 'windows', 'virtualbox', 'vs', 'vmware', 'fusion', 'vs'],
#  ['polar', 'bears', 'movies', 'tv', 'google', 'play'],
#  ['google', 'small', 'business', 'expert'],
#  ['gang', 'knocks', 'cane', 'grove', 'man', 'beats', 'death'],
#  ['ohio', 'state', 'basketball', 'wins', 'sixth', 'beats', 'illinois'],
#  ['rt', 'oracle', 'join', 'processor', 'core', 'gains', 'traction'],
#  ['sweet', 'bakery', 'google'],
#  ['rt', 'saudi', 'arabia', 'severs', 'diplomatic', 'ties', 'iran', 'embassy'],
#  ['rt', 'people', 'social', 'media', 'platforms', 'quick', 'cash'],
#  ['saw', 'ur', 'tweet', 'need', 'google', 'lol', 'large', 'dog'],
#  ['new', 'google', 'chat', 'app', 'destroy', 'facebook', 'messenger'],
#  ['rt', 'af'],
#  ['playing', 'ure', 'apple', 'google'],
#  ['google', 'translates'],
#  ['google',
#   'play',
#   'account',
#   'makes',
#   'realize',
#   'dysfunctional',
#   'teen',
#   'deep',
#   'emotional'],
#  ['latest', 'update', 'brings', 'new', 'skills'],
#  [],
#  ['rt', 'long', 'record', 'attacking', 'foreign', 'diplomatic', 'saudi'],
#  ['rt', 'shenbrood', 'greatest', 'changing', 'google'],
#  ['rt', 'masterminddbs', 'greatest', 'changing', 'google'],
#  ['just', 'like', 'real', 'life'],
#  ['liked', 'video', '10', 'things', 'google'],
#  ['happens', 'access', 'google', 'translate'],
#  [],
#  ['rt', 'time', 'commented', 'google', 'basically', 'old', 'guy'],
#  ['rt', 'support', 'fight'],
#  ['rt', 'seotraversecity', 'greatest', 'changing', 'google'],
#  ['rt', 'kitten', 'called'],
#  ['asked', 'wanda', 'came', 'lives', 'paired'],
#  ['entered', 'win', 'google', 'nexus', '6p'],
#  ['rt', 'google', 'review', 'overdose'],
#  ['rt', 'got7', 'connect', 'bracelet'],
#  [],
#  [],
#  ['irulu',
#   'tablet',
#   'pc',
#   'expro',
#   'x1s',
#   'google',
#   'android',
#   'kitkat',
#   'quad',
#   'core',
#   'black',
#   'bid'],
#  ['new',
#   'irulu',
#   'purple',
#   '16gb',
#   'google',
#   'android',
#   'kitkat',
#   'expro',
#   'x1a',
#   'hd',
#   'tablet',
#   'quad',
#   'core',
#   'bid'],
#  ['house', 'google', 'maps', 'caught', 'inside', 'explains'],
#  ['just', 'received', 'apple', 'day'],
#  ['just', 'received', 'apple', 'day'],
#  ['rt', 'status', 'report', 'ntia', 'drone', 'privacy'],
#  ['braided', 'beard', 'google', 'search'],
#  ['king', 'dark', 'summon', 'app', 'google'],
#  ['google', 'radiation', 'week'],
#  ['tell', 'friends', 'governments'],
#  [],
#  ['somethings', 'change', 'longer', 'want', 'live', 'dusty', 'thing', 'clean'],
#  ['texas',
#   'college',
#   'student',
#   'killed',
#   'new',
#   'eve',
#   'shooting',
#   'cnn',
#   'international'],
#  [],
#  ['check',
#   'page',
#   'hottest',
#   'music',
#   'trends',
#   'search',
#   'favorite',
#   'music'],
#  ['hey', 'check', '2016', 'amazon', 'tips'],
#  ['new', 'event', 'new', 'rank', 'app', 'google'],
#  ['rt'],
#  [],
#  [],
#  ['like', 'boss', 'interested', 'just', 'google', 'pic', 'looks', 'like'],
#  ['rt',
#   'look',
#   'itunes',
#   'just',
#   'google',
#   'popcorn',
#   'pyp',
#   'come',
#   'nyc',
#   'ask'],
#  ['google', 'terms', 'matter', 'bad', 'want'],
#  ['yeah', 'worth', 'google'],
#  ['rt', 'gonna', 'punch', 'google', 'search', 'act', 'brb'],
#  ['pluralsight', 'getting', 'started', 'google', 'play', 'billing'],
#  ['ill', 'send', 'card'],
#  ['google', 'help'],
#  ['gonna', 'just', 'typed', 'wear', 'degrees', 'google'],
#  ['dear',
#   'samsung',
#   'im',
#   'annoyed',
#   'revert',
#   'kitkat',
#   'lollipop',
#   'ive',
#   'contacted',
#   'google',
#   'provider',
#   'opt'],
#  ['check', 'gosford', 'park'],
#  ['british', 'mystery', 'robert', 'altman', 'aleta'],
#  [],
#  [],
#  ['eco', '100', 'wk', '10', 'quiz', 'chapters', '16', '17'],
#  ['pls', 'help'],
#  ['ceo', 'thinks', 'vietnam', 'home', 'big', 'startup', 'scene'],
#  [],
#  [],
#  ['songs', 'play'],
#  ['rt', 'house', 'google', 'maps'],
#  ['instead', 'asking', 'google'],
#  ['google', 'says', 'seo', '2016', 'webpronews'],
#  ['gandalf', 'google', 'gollum', 'apple'],
#  ['going', 'away', 'google', 'search'],
#  ['rt', 'django', 'support', 'just', 'landed', 'help', 'test'],
#  ['try', 'tunnelbear', 'browse', 'like'],
#  ['little',
#   'red',
#   'schoolhouse',
#   'slates',
#   'open',
#   'wicked',
#   'local',
#   'bellingham'],
#  ['rt', 'google', 'glass', 'leaked', 'photos', 'version'],
#  ['ep', 'google', 'play'],
#  [],
#  ['whn',
#   'ur',
#   'fnished',
#   'wth',
#   'paste',
#   'google',
#   'translate',
#   'lsten',
#   'easiest',
#   'way',
#   'mistakes'],
#  ['eminem', 'afraid'],
#  ['google', 'defeats', 'copyright', 'lawsuit', 'waze', 'data'],
#  ['im', 'trying', 'google', 'yeah', 'eat', 'reason', 'dying'],
#  ['techniques',
#   'teaching',
#   'arabic',
#   'foreign',
#   'language',
#   'constructivist',
#   'malaysian',
#   'perspective'],
#  ['rt',
#   'come',
#   'grammatically',
#   'incorrect',
#   'firing',
#   'yo',
#   'ass',
#   'words',
#   'gone',
#   'google'],
#  ['rt'],
#  ['lets',
#   'help',
#   'bernie',
#   'message',
#   'media',
#   'helping',
#   'like',
#   'hillary',
#   'trump'],
#  ['celebrity', 'kim', 'famous', 'playing'],
#  ['new', 'event', 'new', 'rank', 'app', 'google'],
#  ['native',
#   'american',
#   'flute',
#   'meditation',
#   'music',
#   'shamanic',
#   'astral',
#   'healing',
#   'music'],
#  ['rt', 'worried', 'censorship', 'say'],
#  ['course', 'materials', 'statistics', 'easier'],
#  ['rt', 'big', 'lessons', 'successful', 'entrepreneurs', 'work', 'home'],
#  ['google'],
#  ['hip', 'hop', 'alumni', 'blogger', 'channel', '2016'],
#  ['sir', 'tell', 'latest', 'algorithm', '2016'],
#  ['google'],
#  ['paul',
#   'widowed',
#   'mother',
#   'remarried',
#   'settled',
#   'maine',
#   'antique',
#   'digest'],
#  ['rt', 'new', 'symfony', 'dx', 'improvements'],
#  [],
#  [],
#  ['copy', 'paste', 'tweet'],
#  ['phase',
#   'xf',
#   '100mp',
#   'uses',
#   'similar',
#   'a7rii',
#   'sensor',
#   'short',
#   'image',
#   'test'],
#  ['morgan', 'monday'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['eminem', 'real', 'slim', 'shady'],
#  ['entered', 'win', 'google', 'nexus', '6p'],
#  ['rt', 'google', 'question', 'quizlet', 'test'],
#  ['rt', 'google', 'analytics', 'tells', 'redux', 'tutorial', 'passed', '110k'],
#  ['rt', 'great', 'new', 'workout'],
#  [],
#  [],
#  [],
#  [],
#  ['google', 'make', 'good'],
#  ['google', 'whatsapp', 'plan'],
#  ['iphone', 'ipad', 'prices', 'germany', 'private', 'copying', 'fees'],
#  ['wedding',
#   'gown',
#   'survives',
#   'illinois',
#   'farmer',
#   'helps',
#   'reunite',
#   'bride'],
#  ['want', 'play', 'dirty', 'politics', 'google', 'bjp'],
#  ['fused', 'location', 'provider', 'google', 'play', 'provides', 'location'],
#  [],
#  ['turn', 'phone', 'lightsaber', 'google', 'chrome'],
#  ['copy', 'paste', 'tweet'],
#  ['twitpane'],
#  ['digital', 'disappointment', 'tothe', 'end', 'app', 'trends'],
#  ['rt', 'daming', 'handa'],
#  ['company', 'benefit', 'tailored', '0161', '432', '7268'],
#  ['best', 'google'],
#  ['rt',
#   'themeforest',
#   'awesome',
#   'buying',
#   'custom',
#   'templates',
#   'work',
#   'home'],
#  ['rt', 'google', 'earthed', 'house', 'saw', 'window', 'cardboard', 'cut'],
#  ['hello', 'sir', 'watch', 'new', 'video'],
#  ['rt', 'google', 'sexy', 'yoshi'],
#  ['rt',
#   'fashion',
#   'apparel',
#   'retail',
#   'stocks',
#   'end',
#   '2015',
#   'whimper',
#   'wwd'],
#  [],
#  ['fashion', 'apparel'],
#  ['king', 'dark', 'summon', 'app', 'google'],
#  ['company', 'benefit', 'tailored', '0161', '432', '7268'],
#  ['rt',
#   'come',
#   'grammatically',
#   'incorrect',
#   'firing',
#   'yo',
#   'ass',
#   'words',
#   'gone',
#   'google'],
#  ['rt', 'famina', 'produce', 'facebook', 'google'],
#  ['translate', 'google'],
#  ['entered', 'win', 'google', 'nexus', '6p'],
#  ['best', 'google'],
#  ['pay',
#   'luxury',
#   'tax',
#   'rev',
#   'new',
#   'cable',
#   'deal',
#   'kobe',
#   'deal',
#   'isnt',
#   'problem',
#   'google',
#   'moron'],
#  ['entered', 'win', 'google', 'nexus', '6p'],
#  ['entered', 'win', 'google', 'nexus', '6p'],
#  ['schmidt', 'says', 'nation', 'leads'],
#  ['nexus', 'reloaded', 'google', 'nexus', '5x', '6p'],
#  ['morgan', 'monday'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['rt', 'overcome', 'isolation', 'make', 'money', 'online', 'easy', 'money'],
#  ['event', 'e017', 'runnels', 'east', 'dr'],
#  ['automatic', 'alarm', 'e011', 'birdsall', 'st', 'washington', 'ave'],
#  ['honestly', 'google', 'watch', 'captain', 'ron'],
#  ['surprising', 'results', 'google', 'search', 'says'],
#  ['best', 'google'],
#  ['google'],
#  ['rt', 'time', 'commented', 'google', 'basically', 'old', 'guy'],
#  ['make'],
#  ['king', 'dark', 'summon', 'app', 'google'],
#  ['public', 'memory'],
#  ['try', 'subscribers', 'real', 'subscribers', 'youtube', 'google'],
#  ['make'],
#  ['trendy', 'fashionable'],
#  ['rt', 'best', 'paid', 'mod', 'program', 'imploded'],
#  [],
#  ['traffic', 'stop', 'bell', 'ave', '7th', 'st', 'shawnee'],
#  ['eco', '100', 'wk', '11', 'final', 'exam', 'ii'],
#  ['best', 'google'],
#  ['just', 'received', 'tiny', 'village'],
#  ['analysis', 'using', 'clusterprofiler'],
#  ['accessories', 'used', '2015'],
#  ['morgan', 'monday'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['tough', 'getting', 'diagnosed', 'google'],
#  ['best', 'place', 'hide', 'page', 'look'],
#  ['rt',
#   'consider',
#   'deep',
#   'linking',
#   'build',
#   'authority',
#   'make',
#   'fast',
#   'cash'],
#  ['rt', '1d', 'day'],
#  [],
#  [],
#  ['best', 'google'],
#  ['google', 'definition'],
#  ['tips',
#   'passing',
#   'process',
#   'order',
#   'issue',
#   'diagonal',
#   'wantage',
#   'plus',
#   'lmacrfzq'],
#  ['got',
#   'google',
#   'like',
#   'actually',
#   'happens',
#   'thought',
#   'just',
#   'movieish'],
#  ['typed', 'domino', 'google'],
#  ['rt', 'love', 'twitter', 'advertising', 'make', 'fast', 'cash'],
#  ['rt', 'great', 'new', 'workout'],
#  [],
#  [],
#  [],
#  [],
#  ['new', 'psa', 'urges', 'action', 'growing', 'medical', 'marijuana'],
#  ['best', 'google'],
#  ['federal', 'ban', 'medical', 'marijuana', 'lifted', 'reason'],
#  ['rt', 'download', 'google', 'play'],
#  ['physicians',
#   'want',
#   'robust',
#   'studies',
#   'medical',
#   'marijuana',
#   'use',
#   'pittsburgh'],
#  ['going',
#   'gym',
#   'google',
#   'arnold',
#   'schwarzenegger',
#   'shirtless',
#   'recent',
#   'click',
#   'images',
#   'stay',
#   'home'],
#  ['rt',
#   'whn',
#   'ur',
#   'fnished',
#   'wth',
#   'paste',
#   'google',
#   'translate',
#   'lsten',
#   'easiest',
#   'way',
#   'mistakes'],
#  ['virat',
#   'kohli',
#   'congratulates',
#   'indian',
#   'football',
#   'team',
#   'beating',
#   'afghanistan',
#   'saff',
#   'daily',
#   'news',
#   'analysis'],
#  ['screen',
#   'grab',
#   'google',
#   'assertions',
#   'unsupported',
#   'facts',
#   'help',
#   'ur'],
#  ['math', 'labyrinth'],
#  [],
#  [],
#  ['search', 'bc', 'data', 'plan', 'google', 'safari', 'rn', 'rip'],
#  ['best', 'google'],
#  ['lucked', 'finding', 'google'],
#  ['accident', '254', 'peachtree', 'st', 'sw', 'jail'],
#  ['rt', 'literally', 'google'],
#  [],
#  ['jumia'],
#  ['quick',
#   'vaguely',
#   'creepy',
#   'portrait',
#   'studies',
#   'natalie',
#   'portman',
#   'professional',
#   'google'],
#  [],
#  ['oh'],
#  ['southeast',
#   'asian',
#   'country',
#   'ceo',
#   'thinks',
#   'home',
#   'big',
#   'startup',
#   'scene'],
#  ['king', 'dark', 'summon', 'app', 'google'],
#  ['watch', 'load', 'email', 'google'],
#  [],
#  ['internet'],
#  ['rt', 'finance', 'online', 'business', 'empire', 'quick', 'cash'],
#  ['write',
#   'android',
#   'application',
#   'sales',
#   'data',
#   'google',
#   'map',
#   'linkpopular'],
#  ['planned', 'digital', 'video', 'maps', 'like', 'realtime', 'google'],
#  ['rt', 'support', 'fight'],
#  ['kind', 'like', 'google'],
#  ['adding', 'day', 'day', 'repeat', 'event', 'google', 'product', 'forums'],
#  ['best', 'google'],
#  ['new', 'huawei', 'google', 'nexus', '6p', '64gb', '4g', 'lte', 'factory'],
#  ['rt', 'time', 'commented', 'google', 'basically', 'old', 'guy'],
#  ['rt', 'songs', 'play'],
#  [],
#  [],
#  ['1st', 'offer', 'takes'],
#  ['rt',
#   'favorite',
#   'thing',
#   'ces',
#   'night',
#   'google',
#   'flu',
#   'shot',
#   'work',
#   'immediately',
#   'going'],
#  ['planned', 'digital', 'video', 'maps', 'like', 'realtime', 'google'],
#  ['best', 'google'],
#  ['want',
#   'play',
#   'kixeye',
#   'game',
#   'look',
#   'google',
#   'hack',
#   'worth',
#   'playing',
#   'fair',
#   'cheat'],
#  ['entered', 'win', 'google', 'nexus', '6p'],
#  ['playing', 'schulz', 'francesco', 'yates', 'apple', 'google'],
#  ['planned', 'digital', 'video', 'maps', 'like', 'realtime', 'google'],
#  ['qatar', 'slashes', 'gas', 'price', 'india', 'economic', 'times'],
#  ['rt', 'google', 'sexy', 'yoshi'],
#  ['best', 'google'],
#  ['explain', 'slow', 'people'],
#  ['harris',
#   'read',
#   'facebook',
#   'blog',
#   'doctors',
#   'business',
#   'new',
#   'law',
#   'aims',
#   'expose',
#   'big',
#   'pharma',
#   'influence',
#   'phys'],
#  ['planned', 'digital', 'video', 'maps', 'like', 'realtime', 'google'],
#  ['king', 'dark', 'summon', 'app', 'google'],
#  ['google', 'banners'],
#  ['trap', 'did', 'stop'],
#  ['best', 'google'],
#  ['house',
#   'selling',
#   'dirt',
#   'google',
#   'maps',
#   'picture',
#   'explains',
#   'exactly'],
#  ['planned', 'digital', 'video', 'maps', 'like', 'realtime', 'google'],
#  ['rt', 'company', 'benefit', 'tailored', '0161', '432', '7268'],
#  ['google', 'laa'],
#  ['rt', 'jhope', 'limited', 'slogan'],
#  [],
#  ['ph', 'group', 'order'],
#  ['sure', 'try', 'google'],
#  ['dear',
#   'blue',
#   'line',
#   'reaches',
#   'end',
#   'search',
#   'expect',
#   'search',
#   'results',
#   'come'],
#  ['rt', 'company', 'benefit', 'tailored', '0161', '432', '7268'],
#  ['best', 'google'],
#  ['planned', 'digital', 'video', 'maps', 'like', 'realtime', 'google'],
#  ['rt', 'download', 'google', 'play'],
#  ['rt', 'bts', '2nd', 'muster', 'slogan', 'visual', 'shock'],
#  ['rt', 'dot', 'com', 'lunch', 'lunch', 'christmas', 'make', 'money', 'today'],
#  ['science', 'greatest', 'inspiring', 'build', 'future', 'singularity', 'hub'],
#  ['filthy', 'lowlife'],
#  ['rt', 'listening', 'awesome', 'app'],
#  ['seo', 'optimization', 'working', 'like'],
#  ['rt',
#   'read',
#   'google',
#   'search',
#   'history',
#   'funeral',
#   'like',
#   'glad',
#   'just'],
#  ['best', 'google'],
#  ['glowing', 'john', 'digital', 'paintings', 'seattle', 'times'],
#  ['liked', 'video', '10', 'things', 'google'],
#  ['planned', 'digital', 'video', 'maps', 'like', 'realtime', 'google'],
#  ['rt',
#   'muslims',
#   'brag',
#   'gang',
#   'raping',
#   'virgin',
#   'islamic',
#   'immigration'],
#  [],
#  [],
#  ['rt', 'google', 'operating'],
#  ['just', 'received', 'apple', 'day'],
#  ['testing', 'ways', 'replace', 'passwords'],
#  ['rt', 'google', 'earth', 'discoveries'],
#  [],
#  ['just', 'drag', 'image', 'laptop', 'drop', 'search', 'bar'],
#  ['best', 'google'],
#  ['fourth',
#   'seed',
#   'svetlana',
#   'kuznetsova',
#   'progressed',
#   'second',
#   'round',
#   'asb',
#   'classic',
#   'german',
#   'opponent'],
#  ['fourth',
#   'seed',
#   'svetlana',
#   'kuznetsova',
#   'progressed',
#   'second',
#   'round',
#   'asb',
#   'classic',
#   'german',
#   'opponent'],
#  ['know', 'google'],
#  ['rt', 'brilliant', 'buttercup', 'project', '2016'],
#  ['google', 'maps', 'trolling', 'right'],
#  ['use', 'apis'],
#  [],
#  ['planned', 'digital', 'video', 'maps', 'like', 'realtime', 'google'],
#  ['rt', 'sunbro', 'moonbro', 'looking'],
#  ['rt', 'wwic', 'seoul', 'live', 'stage'],
#  ['irulu',
#   'google',
#   'android',
#   'capacitive',
#   'pink',
#   'tablet',
#   'pc',
#   '8gb',
#   'quad',
#   'core',
#   'keyboard'],
#  ['rt', 'expensive', 'keywords', 'google', 'adwords'],
#  ['best', 'google'],
#  ['rt', 'company', 'benefit', 'tailored', '0161', '432', '7268'],
#  ['irulu',
#   'google',
#   'android',
#   'capacitive',
#   'pink',
#   'tablet',
#   'pc',
#   '8gb',
#   'quad',
#   'core',
#   'keyboard'],
#  ['rt', '50', 'accounts', 'marketer'],
#  [],
#  ['liked', 'video', 'google', 'want', 'google'],
#  ['planned', 'digital', 'video', 'maps', 'like', 'realtime', 'google'],
#  ['webmaster', 'tools', 'better', 'communication', 'google'],
#  ['dalek', 'star', 'wars', 'google', 'cardboard', 'firefly', 'jayne'],
#  ['new', 'event', 'new', 'rank', 'app', 'google'],
#  ['know', 'google', 'north'],
#  ['phones',
#   'offers',
#   'fosmon',
#   'sparkle',
#   'bling',
#   'star',
#   'jewel',
#   'diamond',
#   'hybrid',
#   'case',
#   'google'],
#  ['root',
#   'cause',
#   'prize',
#   'warburg',
#   'proves',
#   'gilberti',
#   'endless',
#   'h20',
#   'slows'],
#  ['afps', 'registration', 'link', 'registration', 'kindly', 'share'],
#  ['backlink', 'google', 'rankings', 'highly', 'competitive', 'keywords'],
#  ['free', '40z'],
#  ['best', 'google'],
#  ['planned', 'digital', 'video', 'maps', 'like', 'realtime', 'google'],
#  ['check', 'google'],
#  ['donald', 'social', 'media', 'genius', 'way', 'white', 'guardian'],
#  ['king', 'dark', 'summon', 'app', 'google'],
#  ['rt', 'suga', 'photo', 'slogan', 'gift'],
#  ['rt', 'rap', 'monster', 'photo', 'slogan', 'hide', 'seek'],
#  ['google', 'appsperience', 'microsoft', 'stories'],
#  ['best', 'google'],
#  ['rt', 'tweetsheet', 'cruel'],
#  ['rt',
#   'come',
#   'grammatically',
#   'incorrect',
#   'firing',
#   'yo',
#   'ass',
#   'words',
#   'gone',
#   'google'],
#  ['rt', 'company', 'benefit', 'tailored', '0161', '432', '7268'],
#  [],
#  ['google', 'inspector', 'good'],
#  ['rt', 'accident', '254', 'peachtree', 'st', 'sw', 'jail'],
#  ['planned', 'digital', 'video', 'maps', 'like', 'realtime', 'google'],
#  ['best', 'google'],
#  ['google', 'lol', 'idea', 'lemme', 'ok'],
#  ['irulu',
#   'google',
#   'android',
#   'capacitive',
#   'pink',
#   'tablet',
#   'pc',
#   '8gb',
#   'quad',
#   'core',
#   'keyboard'],
#  ['google', 'wanted', 'trailer'],
#  ['planned', 'digital', 'video', 'maps', 'like', 'realtime', 'google'],
#  ['rt', 'accident', '254', 'peachtree', 'st', 'sw', 'jail'],
#  ['backlink', 'google', 'rankings', 'highly', 'competitive', 'keywords'],
#  ['rt', 'accident', '254', 'peachtree', 'st', 'sw', 'jail'],
#  ['rt', 'time', 'commented', 'google', 'basically', 'old', 'guy'],
#  ['playing', 'del', 'rio', 'apple', 'google'],
#  ['people', 'realize', 'large', 'companies', 'avoid', 'taxes', 'way', 'apple'],
#  ['best', 'google'],
#  ['rt', 'check', 'tv', 'interview', 'elise'],
#  ['credit', 'score', 'hit', 'plateau', 'news'],
#  ['addressing', 'climate'],
#  ['google', 'ford', 'rumored', 'announce', 'partnership', 'ces'],
#  ['2015',
#   'rookies',
#   'star',
#   'longevity',
#   'bears',
#   'patch',
#   'jay',
#   'cutler',
#   'kevin',
#   'white'],
#  ['planned', 'digital', 'video', 'maps', 'like', 'realtime', 'google'],
#  ['rt', '2nd', 'muster', 'jungkook', 'photo', 'slogan', 'stick'],
#  ['great', 'android', 'game', 'war', 'ww2', 'air', 'strike', '1942'],
#  ['2008', 'adrian', 'peterson', 'lot', 'topps', 'chrome'],
#  ['rt', 'time', 'commented', 'google', 'basically', 'old', 'guy'],
#  ['hillie', 'quit', 'secdef', 'job', 'health', 'google', 'needs', 'just'],
#  ['new',
#   'project',
#   'fi',
#   'tablet',
#   'plans',
#   'charge',
#   'device',
#   'fees',
#   'ars',
#   'technica'],
#  ['best', 'google'],
#  ['rt', 'marines', 'drop', 'simple', 'reason', 'cnet'],
#  ['google', 'shit'],
#  ['wolf', 'cinema', 'projectors', 'wider', 'upgraded', 'hdmi', 'twice'],
#  ['washington', 'redskins', 'close', 'regular', 'season', 'beating'],
#  ['pone', 'en', 'google'],
#  ['planned', 'digital', 'video', 'maps', 'like', 'realtime', 'google'],
#  ['google', 'maps', 'shows', 'el', 'camino', 'bit', 'weird'],
#  ['rt',
#   'meet',
#   'twitter',
#   'easiest',
#   'way',
#   'save',
#   'tweets',
#   'search',
#   'term',
#   'google'],
#  ['best', 'google'],
#  ['celebrity', 'kim', 'famous', 'playing'],
#  ['eco', '302', 'exam', 'quizzes', 'strayer'],
#  ['new', 'video'],
#  [],
#  [],
#  ['company', 'shares', 'google', 'rally'],
#  [],
#  [],
#  ['seo', 'implications', 'search', 'quality', 'raters', 'guidelines'],
#  ['planned', 'digital', 'video', 'maps', 'like', 'realtime', 'google'],
#  ['come', 'join', 'epic', 'invite', '2343598528', 'google'],
#  ['rt', 'google', 'sexy', 'yoshi'],
#  ['rt',
#   '30',
#   'seconds',
#   'love',
#   '5k',
#   'followers',
#   'giveaway',
#   'play',
#   'gift'],
#  ['rt', 'oops', 'google'],
#  ['entered', 'win', 'google', 'nexus', '6p'],
#  ['liked', 'video', 'like', 'google', 'translate'],
#  ['rt', '10', 'ways', 'ranked', 'higher', 'google', 'search', 'engine'],
#  ['best', 'google'],
#  ['rt', 'nerd', 'ass', 'girl'],
#  ['visitors'],
#  ['planned', 'digital', 'video', 'maps', 'like', 'realtime', 'google'],
#  ['buy',
#   'computer',
#   'irulu',
#   'google',
#   'android',
#   'tablet',
#   'pc',
#   '8g',
#   'quad',
#   'core',
#   '10',
#   'inch'],
#  ['buy',
#   'computer',
#   'new',
#   'inch',
#   'google',
#   'android',
#   'tablet',
#   'pc',
#   '8gb',
#   'quad',
#   'core',
#   '10',
#   'inch'],
#  ['maharashtra', 'govt', 'bars', 'employees', 'using'],
#  ['hi',
#   'wanna',
#   'know',
#   'make',
#   'monthly',
#   'google',
#   'cb',
#   'using',
#   'simple',
#   'visit',
#   'web'],
#  ['hi',
#   'wanna',
#   'know',
#   'make',
#   'monthly',
#   'google',
#   'cb',
#   'using',
#   'simple',
#   'visit',
#   'web'],
#  ['hi',
#   'wanna',
#   'know',
#   'make',
#   'monthly',
#   'google',
#   'cb',
#   'using',
#   'simple',
#   'visit',
#   'web'],
#  ['best', 'google'],
#  ['intelligence',
#   'nonprofit',
#   'openai',
#   'launches',
#   'backing',
#   'elon',
#   'musk',
#   'sam'],
#  [],
#  ['computer',
#   'shop',
#   'irulu',
#   'google',
#   'android',
#   'tablet',
#   'pc',
#   '8g',
#   'quad',
#   'core',
#   '10',
#   'inch'],
#  ['computer',
#   'shop',
#   'new',
#   'inch',
#   'google',
#   'android',
#   'tablet',
#   'pc',
#   '8gb',
#   'quad',
#   'core',
#   '10',
#   'inch'],
#  ['googleexpertuk', 'supports', 'swedish', 'chef', 'muppetsstudio'],
#  ['washington', 'mongoloids', 'close', 'regular', 'season', 'beating'],
#  ['come', 'join', 'epic', 'invite', '1865846254', 'google'],
#  ['new', 'dfoshay', 'facebook', 'events', 'google', 'map'],
#  ['new', 'bmunna', 'google', 'xml', 'regenerate', 'sitemap'],
#  ['planned', 'digital', 'video', 'maps', 'like', 'realtime', 'google'],
#  ['google'],
#  ['rt', 'sa', 'mga', 'team', 'abroad', 'wants', 'aldub'],
#  [],
#  [],
#  [],
#  [],
#  ['rt', 'company', 'benefit', 'tailored', '0161', '432', '7268'],
#  ['fpa',
#   'client',
#   'desire',
#   'education',
#   'driving',
#   'financial',
#   'adviser',
#   'magazine'],
#  ['a33',
#   'google',
#   'android',
#   'quad',
#   'core',
#   'dual',
#   'camera',
#   '8gb',
#   'tablet',
#   'pc',
#   'wifi',
#   'bluetooth',
#   'bid'],
#  ['googleexpertuk', 'company', 'benefit', 'tailored', '0161', '432', '7268'],
#  ['google', 'fuck'],
#  ['rt', 'google', 'shit'],
#  ['google', 'daily', 'stories'],
#  ['best', 'google'],
#  ['googleexpertuk', 'company', 'benefit', 'tailored', '0161', '432', '7268'],
#  ['nice', 'google', 'try', 'reading', 'things', 'cite', 'post'],
#  ['rt',
#   'grand',
#   'jury',
#   'just',
#   'decided',
#   'indict',
#   'cop',
#   'killed',
#   'tamir',
#   'rice'],
#  ['google', 'bestfriends'],
#  ['planned', 'digital', 'video', 'maps', 'like', 'realtime', 'google'],
#  ['apparently', 'google', 'understands'],
#  ['just', 'received', 'titan', 'crusher'],
#  ['just',
#   'pinned',
#   'google',
#   'lawyer',
#   'just',
#   'pinned',
#   'google',
#   'lawyer',
#   'just'],
#  ['just',
#   'pinned',
#   'google',
#   'lawyer',
#   'just',
#   'pinned',
#   'google',
#   'lawyer',
#   'just'],
#  ['best', 'google'],
#  ['rt', 'send', 'millions', 'visitors', 'google', '2016'],
#  ['just', 'received', 'winter', 'coming'],
#  ['ways', 'trying', 'help', 'leaf'],
#  ['rt', 'remembering', 'rick', 'aviles'],
#  ['planned', 'digital', 'video', 'maps', 'like', 'realtime', 'google'],
#  ['tells', 'homeowners', 'solar', 'panels'],
#  ['just', 'pinned', 'google', 'lawyer', 'just', 'pinned', 'google', 'lawyer'],
#  ['best', 'google'],
#  ['rt',
#   'reading',
#   'interesting',
#   'article',
#   'millions',
#   'visitors',
#   'google',
#   '2016'],
#  ['new', 'event', 'new', 'rank', 'app', 'google'],
#  ['king', 'dark', 'summon', 'app', 'google'],
#  ['planned', 'digital', 'video', 'maps', 'like', 'realtime', 'google'],
#  ['rank',
#   'google',
#   'search',
#   'page',
#   'new',
#   'marketing',
#   'tool',
#   'pharma',
#   'franchise'],
#  ['google'],
#  ['new', 'event', 'new', 'rank', 'app', 'google'],
#  ['rt',
#   'read',
#   'google',
#   'search',
#   'history',
#   'funeral',
#   'like',
#   'glad',
#   'just'],
#  ['king', 'dark', 'summon', 'app', 'google'],
#  ['best', 'google'],
#  ['customizable', 'modular', 'product', 'hanging', 'divider'],
#  ['need', 'grow'],
#  ['adwords', 'campaigns', 'ads', 'displaying', 'competitive'],
#  ['google', 'rnkd'],
#  [],
#  ['business', 'seen', 'prominently', 'bing'],
#  ['planned', 'digital', 'video', 'maps', 'like', 'realtime', 'google'],
#  ['liked', 'video', '10', 'things', 'google'],
#  ['roboticists', 'charge', 'bigdog', 'droids', 'pulling', 'sleigh', 'mark'],
#  ['estates', 'horsham', 'pa'],
#  [],
#  ['iobm',
#   'degree',
#   'recipients',
#   'advised',
#   'forget',
#   'corporate',
#   'social',
#   'responsibility',
#   'news',
#   'international'],
#  ['muslims', 'islamists', 'read'],
#  ['tip', 'wintry', 'heating', 'bills', 'bite'],
#  ['lower', 'bills', 'winter', 'fixes', 'dailyfinance', 'savings', 'exper'],
#  ['best', 'google'],
#  ['swedish', 'google', 'autocomplete'],
#  [],
#  ['just',
#   'launch',
#   'google',
#   'authenticator',
#   'app',
#   'watch',
#   'numbers',
#   'change'],
#  ['mike', 'pipkins'],
#  ['rt',
#   'second',
#   'day',
#   'college',
#   'kid',
#   'sat',
#   'google',
#   'word',
#   'results',
#   'came'],
#  ['expanding',
#   'project',
#   'compare',
#   'benefits',
#   'installing',
#   'solar',
#   'panels'],
#  ['feels', 'pretty'],
#  ['rt', 'google', 'sniper', 'great', 'make', 'couple', 'day'],
#  [],
#  ['check', 'link'],
#  ['dont', 'know', 'history', 'learn', 'speak', 'hell', 'google'],
#  ['planned', 'digital', 'video', 'maps', 'like', 'realtime', 'google'],
#  ['rt', '10', 'ways', 'ranked', 'higher', 'google', 'search', 'engine'],
#  ['google', 'places', 'help', 'community', 'discover', 'chiropractic'],
#  ['best', 'google'],
#  ['rt',
#   'read',
#   'google',
#   'search',
#   'history',
#   'funeral',
#   'like',
#   'glad',
#   'just'],
#  ['wilding', 'tonight', 'sure', 'nearest', 'plantation', 'google'],
#  ['planned', 'digital', 'video', 'maps', 'like', 'realtime', 'google'],
#  ['new', 'event', 'new', 'rank', 'app', 'google'],
#  ['android', 'apps', 'revealed', 'hidden', 'google', 'play'],
#  ['finally', 'acknowledges', 'tablets', 'different', 'soon', 'allow', 'bid'],
#  ['hardware',
#   'specifications',
#   'information',
#   'google',
#   'provide',
#   'easy',
#   'way'],
#  ['personal', 'development'],
#  ['playing', 'chandler', 'apple', 'google'],
#  ['hadi', 'reveal', 'pas', 'leaders', 'cooperating', 'umno', 'malaysiakini'],
#  ['rt', '27th', 'birthday', 'special', 'goods', '3d', 'yoseop', 'usb'],
#  [],
#  ['google', 'helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['2016', 'smart', 'tv', 'remote', 'controls', 'devices', 'engadget'],
#  ['planned', 'digital', 'video', 'maps', 'like', 'realtime', 'google'],
#  ['new',
#   'york',
#   'eagles',
#   'audition',
#   'tarnishes',
#   'giants',
#   'tribute',
#   'tom'],
#  ['just', 'google', 'search', 'chip', 'kelly', 'looks', 'happier', 'oregon'],
#  ['nasty', 'update', 'crashed', 'app', 'sent', 'items', 'day'],
#  ['rt', 'google', 'controls', 'search', 'market', 'integrates'],
#  ['goog', 'working', 'auto', 'industry'],
#  ['rt', 'plan', '2016', 'success', 'using', 'google', 'calendar'],
#  ['does', 'mean'],
#  ['rt', 'google', 'nice', 'human'],
#  ['amazing', 'google', 'hacks', 'change', 'internet', 'addicted'],
#  ['gun', 'battles', 'rage', 'near', 'indian', 'consulate', 'afghan', 'city'],
#  ['planned', 'digital', 'video', 'maps', 'like', 'realtime', 'google'],
#  ['operation', 'enters', 'forces', 'rushed', 'air', 'base', 'hindu'],
#  ['link', 'database', 'google', 'form'],
#  ['android', 'lollipop', 'percent', 'active', 'google'],
#  ['server', 'saves', 'day', 'family', 'accidentally', 'leaves', 'booth'],
#  ['hot',
#   'deals',
#   'fosmon',
#   'sparkle',
#   'bling',
#   'star',
#   'jewel',
#   'diamond',
#   'hybrid',
#   'case',
#   'google',
#   'huawei',
#   'nexus'],
#  ['rt', 'program', 'google', 'loon'],
#  ['come', 'join', 'epic', 'invite', '2592041653', 'google'],
#  ['rt', 'program', 'google', 'loon'],
#  ['south', 'nsri', 'kept', 'toes', 'weekend'],
#  ['rt', 'wilding', 'tonight', 'sure', 'nearest', 'plantation', 'google'],
#  ['planned', 'digital', 'video', 'maps', 'like', 'realtime', 'google'],
#  ['playing', 'gave', 'love', 'heights', 'affair', 'apple', 'google'],
#  ['100',
#   'injured',
#   'massive',
#   'earthquake',
#   'jolts',
#   'northeastern',
#   'india',
#   'time'],
#  ['method',
#   'far',
#   'meddle',
#   'google',
#   'adwords',
#   'email',
#   'chouse',
#   'xlaoctdi'],
#  ['liked', 'video', 'people', 'search', 'google', 'bro'],
#  ['google', 'releases', 'enterprise', 'tools', 'clear'],
#  ['oogle', 'google'],
#  ['new', 'rule', 'impress', 'son'],
#  ['google',
#   'news',
#   'gun',
#   'battles',
#   'rage',
#   'near',
#   'indian',
#   'consulate',
#   'afghan',
#   'city'],
#  ['create', 'google', 'account'],
#  ['a33',
#   'google',
#   'android',
#   'quad',
#   'core',
#   'dual',
#   'camera',
#   '8gb',
#   'tablet',
#   'pc',
#   'wifi',
#   'bluetooth',
#   'bid'],
#  ['pluralsight',
#   'getting',
#   'started',
#   'google',
#   'play',
#   'pluralsight',
#   'getting',
#   'started',
#   'google',
#   'play'],
#  ['planned', 'digital', 'video', 'maps', 'like', 'realtime', 'google'],
#  ['rt',
#   'free',
#   'internet',
#   'marketing',
#   'podcast',
#   '205a',
#   'configuring',
#   'google',
#   'authorship'],
#  ['gunbattle',
#   'underway',
#   'near',
#   'indian',
#   'consulate',
#   'afghanistan',
#   'new',
#   'york',
#   'times'],
#  [],
#  ['pluralsight', 'getting', 'started', 'google', 'play', 'billing'],
#  ['answers'],
#  ['larry', 'page', 'answers', 'fundamental'],
#  [],
#  [],
#  ['google', 'search', 'info', 'sources', 'does'],
#  ['rt', 'trust', 'google', 'translate'],
#  ['rt', 'trying', 'reference', 'apartment', 'opm', 'actual'],
#  ['know', 'afps', 'pre', 'symposium'],
#  ['rt', 'helps', 'analyze', 'rooftop', 'good', 'deal'],
#  ['rt', '27th', 'birthday', 'special', 'goods', '3d', 'yoseop', 'usb'],
#  [],
#  ['new',
#   'oem',
#   'battery',
#   'google',
#   'nexus',
#   'e960',
#   'lg',
#   'optimus',
#   '2100mah',
#   'bid'],
#  ['planned', 'digital', 'video', 'maps', 'like', 'realtime', 'google'],
#  ['dropout', 'google', 'career', 'choices'],
#  ['rt', 'accident', '254', 'peachtree', 'st', 'sw', 'jail'],
#  ['rt', 'tacky', 'google', 'address', 'rent'],
#  ['thank', 'thank'],
#  ['banner', '2009y', 'meltdown'],
#  ['rt',
#   'googleexpertuk',
#   'company',
#   'benefit',
#   'tailored',
#   '0161',
#   '432',
#   '7268'],
#  ['rt',
#   'googleexpertuk',
#   'company',
#   'benefit',
#   'tailored',
#   '0161',
#   '432',
#   '7268'],
#  ['rt', 'really', 'excited', 'need'],
#  [],
#  [],
#  ['google', 'right', 'wrong', 'explaining'],
#  ['fattyttt',
#   'sister',
#   'pooping',
#   'told',
#   'look',
#   'google',
#   'images',
#   'oh',
#   'really',
#   'did'],
#  ['yeah', 'stay', 'google', 'lol', 'nervous', 'shit'],
#  ['ce', 'moment', 'pepsupmusic', 'love', 'like', 'ellie', 'goulding'],
#  ['google', 'play', 'store'],
#  [],
#  ['dilly', 'dally'],
#  ['planned', 'digital', 'video', 'maps', 'like', 'realtime', 'google'],
#  ['search',
#   'engines',
#   'instantly',
#   'submit',
#   'website',
#   '500',
#   'search',
#   'engines',
#   'including',
#   'yahoo'],
#  ['meteor', 'binocular', 'comet', 'winter'],
#  ['sb', 'eagles', 'giants', 'things'],
#  ['just', 'woke', 'google', 'actually', 'went', 'understand', 'better'],
#  ['hav', 'looking'],
#  ['rt',
#   'lmao',
#   'checking',
#   'hong',
#   'kong',
#   'google',
#   'earth',
#   'cruise',
#   'middle'],
#  ['heard', 'mow', 'lawn', 'freaky', 'piece', 'google'],
#  ['celebrity', 'kim', 'famous', 'playing'],
#  ['rt'],
#  ['opening', 'commissions', 'save', 'study', 'thank'],
#  ['slots', 'available'],
#  [],
#  ['rt', 'new', 'album'],
#  [],
#  [],
#  [],
#  ['google', 'play'],
#  [],
#  ['spotify'],
#  ['rt',
#   'just',
#   'launch',
#   'google',
#   'authenticator',
#   'app',
#   'watch',
#   'numbers',
#   'change'],
#  ['eco', '302', 'week', 'quiz', 'strayer'],
#  ['tyrneathem', 'rt', 'entered', 'win', 'google', 'nexus', '6p', 'makeuseof'],
#  ['rt', 'diliat', 'nih', 'chubby', 'bunny'],
#  ['rt', 'download', 'dashy', 'square'],
#  ['rt', 'luxury', 'real', 'estate', 'web', 'design'],
#  ['dante_chutzpah', 'entered', 'win', 'google', 'nexus', '6p', 'makeuseof'],
#  ['rt', 'competes', 'best'],
#  ['reload', 'tabs', 'google', 'chrome', 'extension'],
#  ['earth', 'song', 'carmen', 'monarcha'],
#  ['dont',
#   'know',
#   'comes',
#   'google',
#   'image',
#   'search',
#   'yiffpup',
#   'just',
#   'like',
#   'trying',
#   'make',
#   'bf',
#   'make',
#   'bad',
#   'life',
#   'choices'],
#  ['leadcorp', 'media'],
#  ['rt', 'humble', 'beginnings'],
#  [],
#  [],
#  ['google'],
#  ['book', 'ebook', 'google', '24', 'hours'],
#  ['a33',
#   'google',
#   'android',
#   'quad',
#   'core',
#   'dual',
#   'camera',
#   '8gb',
#   'tablet',
#   'pc',
#   'wifi',
#   'bluetooth',
#   'bid'],
#  ['android', 'apps', 'revealed', 'hidden', 'google', 'play', 'store', 'link'],
#  ['google', 'recommends', 'web', 'pages'],
#  ['rt', 'morgan', 'monday'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['associated', 'manning', 'leads', 'broncos', 'past', 'chargers'],
#  ['rt', 'company', 'benefit', 'tailored', '0161', '432', '7268'],
#  ['rt', 'google', 'tips', 'making', 'mind', 'maps'],
#  ['google', 'watches'],
#  ['hotline', 'blings', 'google', 'notifications', 'does'],
#  ['celebrity', 'kim', 'famous', 'playing'],
#  ['rt',
#   'dont',
#   'know',
#   'comes',
#   'google',
#   'image',
#   'search',
#   'yiffpup',
#   'just',
#   'like',
#   'trying',
#   'make',
#   'bf',
#   'make',
#   'bad',
#   'life',
#   'choices'],
#  ['rt',
#   'people',
#   'realize',
#   'large',
#   'companies',
#   'avoid',
#   'taxes',
#   'way',
#   'apple'],
#  ['thought', 'german', 'uses', 'google', 'translate'],
#  ['celebrity', 'kim', 'famous', 'playing'],
#  ['lenovo',
#   'google',
#   'make',
#   'project',
#   'tango',
#   'announcement',
#   'january',
#   '7th',
#   'ces'],
#  ['funny', 'statuses', 'android', 'apps', 'google', 'play'],
#  ['just', 'amazed', 'feature', 'day'],
#  ['rt', 'company', 'benefit', 'tailored', '0161', '432', '7268'],
#  ['photo', 'google', 'new', 'weedlion', 'rig'],
#  ['rt', '2016', 'smart', 'tv', 'remote', 'controls', 'devices', 'engadget'],
#  ['baby', 'nah', 'link'],
#  ['experience', 'installing', 'google', 'page', 'speed', 'module'],
#  [],
#  [],
#  ['new', 'event', 'new', 'rank', 'app', 'google'],
#  ['rt', 'google', 'add', 'documents', 'class', 'folder'],
#  ['rt',
#   'spend',
#   'free',
#   'time',
#   'reading',
#   'inspirational',
#   'quotes',
#   'google',
#   'successful',
#   'day'],
#  ['finish', 'google', 'facts', 'left'],
#  ['new', 'york', 'peyton', 'manning', 'returns', 'leads', 'broncos', 'seed'],
#  ['rt', 'adams', 'carvalho', 'picdit'],
#  ['nope'],
#  ['tyrneathem', 'rt', 'entered', 'win', 'google', 'nexus', '6p', 'makeuseof'],
#  [],
#  [],
#  ['read', 'opening', 'link', 'comment', 'important', 'issue'],
#  ['gas', 'leak', 'e059', 'main', 'st', 'ib', 'reedcrest'],
#  ['dante_chutzpah', 'entered', 'win', 'google', 'nexus', '6p', 'makeuseof'],
#  ['event', 'e021', 'elmridge', 'st', 'latma', 'dr'],
#  ['google',
#   'triyng',
#   'ot',
#   'picture',
#   'sof',
#   'exact',
#   'palcement',
#   'fo',
#   'kandas',
#   'tattoo',
#   'ifoudn',
#   'thsi',
#   'isntead'],
#  ['developer', 'matthew'],
#  [],
#  ['rt', 'download', 'google', 'play'],
#  ['lol', 'google', 'guys', 'haha'],
#  ['feel', 'police', 'respect', 'people'],
#  ['antebellum', 'united', 'states', 'just', 'bought', 'enslaved'],
#  ['new', 'book', 'social', 'business', 'daily', 'star'],
#  ['amla'],
#  ['rt', 'literary', 'agent', 'google', 'query'],
#  ['google'],
#  ['ive', 'skydiving', 'ive', 'zoomed', 'google', 'earth', 'really', 'really'],
#  ['yessssss', 'google', 'general'],
#  ['planning',
#   'trip',
#   'hire',
#   'cab',
#   'advance',
#   'information',
#   'click',
#   'link'],
#  ['rt', 'th8', 'come', 'join'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['lenovo',
#   'google',
#   'officially',
#   'announce',
#   'project',
#   'tango',
#   'january',
#   'ces'],
#  ['rt', 'time', 'commented', 'google', 'basically', 'old', 'guy'],
#  ['associated', 'pats', 'miss', 'chance', 'clinch', 'losing', 'miami'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['rt',
#   'tyrneathem',
#   'rt',
#   'entered',
#   'win',
#   'google',
#   'nexus',
#   '6p',
#   'makeuseof'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['site', 'giving', 'away', 'free', 'google', 'play', 'codes', 'play'],
#  ['rt', 'download', 'google', 'play'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['videos', 'people', 'crying', 'things', 'happened', '2010', 'make', 'years'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['story', 'abuse', 'inspiring', 'survivors', 'vocativ'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['omg', 'thanks', 'google', 'translate', 'teacher'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['lenovo',
#   'google',
#   'officially',
#   'announce',
#   'project',
#   'tango',
#   'january',
#   'ces'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['thanks'],
#  ['thank', 'google'],
#  [],
#  ['plans', 'winter', 'shopping', 'hubby'],
#  ['rt', 'download', 'google', 'play'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['kind',
#   'thing',
#   'waiting',
#   'im',
#   'getting',
#   'google',
#   'cardboard',
#   'soon',
#   'possible',
#   'xd',
#   'know',
#   'let'],
#  ['just', 'received', 'diligent'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['downloaded', 'google', 'translate', 'preps', 'terms'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['rt', 'lol', 'google', 'guys', 'haha'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['just', 'google', 'tv', 'shows', 'click', 'pages'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['google', 'help', 'answer', 'homework'],
#  ['amazing', 'google', 'hacks', 'change', 'internet'],
#  ['rt', 'google', 'maps', 'icon'],
#  [],
#  [],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['creating',
#   'unartificial',
#   'websites',
#   'lost',
#   'self',
#   'transit',
#   'chain',
#   'zenithal',
#   'qfhbnf'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['rt'],
#  ['opening', 'commissions', 'save', 'study', 'thank'],
#  ['slots', 'available'],
#  [],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['rt', 'company', 'benefit', 'tailored', '0161', '432', '7268'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['gunbattle',
#   'underway',
#   'near',
#   'indian',
#   'consulate',
#   'afghanistan',
#   'new',
#   'york',
#   'times'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['google', 'em'],
#  ['a33',
#   'google',
#   'android',
#   'quad',
#   'core',
#   'dual',
#   'camera',
#   '8gb',
#   'tablet',
#   'pc',
#   'wifi',
#   'bluetooth',
#   'bid'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['monokon', 'internet', 'things', 'future'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['swahili', 'thing', 'run', '10', 'languages', 'google', 'translate'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  [],
#  ['associated', 'seahawks', 'rout', 'cardinals'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['tried', 'google', 'far'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['rt', 'google', 'controls', 'search', 'market', 'integrates'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['new',
#   'mathematical',
#   'breakthrough',
#   'mathematical',
#   'difficulty',
#   'creating',
#   'optimal',
#   'pr'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['diary', 'young', 'anne', 'frank', 'trending', 'philippine'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['giants', 'check', 'latest', 'ny', 'giants', 'update'],
#  ['rt', 'really', 'like', 'work', 'answer'],
#  ['motivates', 'want', 'unusual', 'news', 'kamloops'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['penalty', 'recovery', 'guide', 'execs'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['need', 'fbeye', 'lol'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['rt',
#   'laying',
#   'naked',
#   'outside',
#   'just',
#   'thought',
#   'google',
#   'maps',
#   'taking',
#   'annual',
#   'satellite',
#   'pictures',
#   'right'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['buy',
#   'usa',
#   'instagram',
#   'followers',
#   'buy',
#   'website',
#   'traffic',
#   'verified',
#   'google',
#   'analytics'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['sun', 'january', '2016'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['today', 'google', 'suggested', 'search', 'images'],
#  ['came'],
#  ['google', 'making', 'ev', 'ramasamy', 'naaickar'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['tried', 'just', 'google', 'ones', 'just', 'got', 'ep', '200', 'lol'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['helps', 'analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['rt', 'just', 'google', 'synonyms', 'word'],
#  [],
#  ['irony', 'lost'],
#  ['rt', 'google', 'bio', 'let', 'copy', 'paste'],
#  ['brackets', 'changed', 'sizing', 'make', 'reading'],
#  ['google', 'trying', 'say', 'life'],
#  ['self',
#   'fixed',
#   'occurring',
#   'google',
#   '40',
#   'days',
#   'recondite',
#   'automation',
#   'opmg'],
#  ['google', 'cultural', 'institute'],
#  ['create', 'galleries', 'share', 'favourite', 'finds'],
#  [],
#  ['celebrity', 'kim', 'famous', 'playing'],
#  ['love', 'check', 'fighting'],
#  ['king', 'dark', 'summon', 'app', 'google'],
#  [],
#  ['rt', 'company', 'benefit', 'tailored', '0161', '432', '7268'],
#  ['interested',
#   'helping',
#   'test',
#   'mazevr',
#   'google',
#   'cardboard',
#   'iphone',
#   'dm',
#   'email',
#   'testflight',
#   'requires'],
#  ['brokering', 'premium'],
#  ['rt', 'google', 'making', 'ev', 'ramasamy', 'naaickar'],
#  ['liked', 'video', '10', 'things', 'google'],
#  ['rt', 'week', 'power'],
#  ['google', 'cute', 'ways', 'ask', 'cause', 'ideas', 'suck', 'asf'],
#  ['sb',
#   'colts',
#   'titans',
#   'final',
#   'colts',
#   'beat',
#   'titans',
#   'likely',
#   'chuck',
#   'final'],
#  ['king', 'dark', 'summon', 'app', 'google'],
#  ['rt'],
#  [],
#  ['leave', 'sherifs', 'office', 'comments', 'google'],
#  ['sure', 'sort', 'like', 'google', 'questions', 'knows'],
#  ['answers'],
#  ['answers', 'fundamental'],
#  [],
#  ['agoa', 'trade', 'ties', 'jeopardy', 'enca'],
#  ['new', 'event', 'new', 'rank', 'app', 'google'],
#  ['google', 'think', 'know'],
#  ['bootleg', 'version', 'tfa'],
#  ['best', 'advice', 'received', 'google', 'numb', 'emotional', 'pain'],
#  ['thanks', 'following', 'look', 'linkedin', 'pinterest', 'ya'],
#  ['eco', '302', 'week', 'quiz'],
#  ['a33',
#   'google',
#   'android',
#   'quad',
#   'core',
#   'dual',
#   'camera',
#   '8gb',
#   'tablet',
#   'pc',
#   'wifi',
#   'bluetooth',
#   'bid'],
#  ['analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['analyze', 'rooftop', 'solar', 'panels', 'good', 'deal'],
#  ['summary', 'rise', 'hate'],
#  ['reliable',
#   'seattle',
#   'town',
#   'car',
#   'hire',
#   'services',
#   'information',
#   'click',
#   'link'],
#  ['king', 'dark', 'summon', 'app', 'google'],
#  ['listening', 'forgot', 'wanye'],
#  ['rt', '10', 'google', 'docs', 'posts', '2015'],
#  ['hope', 'works'],
#  ['google'],
#  ['associated', 'steelers', 'sneak', 'afc', 'playoffs', 'win'],
#  ['rt', 'company', 'benefit', 'tailored', '0161', '432', '7268'],
#  ['just', 'saw', 'sharing'],
#  ['waka', 'flocka', 'young', 'sizzle', 'new', 'year'],
#  ['ya', 'fios', 'place', 'hopefully', 'google', 'fiber'],
#  ['spyhuman', 'mobile', 'track', 'application', 'gps', 'logs', 'recording'],
#  [],
#  ['thankful', 'google', 'chromecast', 'letting', 'stream', 'music', 'phone'],
#  ['rt', 'supports', 'swedish', 'chef'],
#  ['rt',
#   'come',
#   'grammatically',
#   'incorrect',
#   'firing',
#   'yo',
#   'ass',
#   'words',
#   'gone',
#   'google'],
#  ['use', 'google', 'effectively'],
#  ['rt',
#   'use',
#   'google',
#   'research',
#   'just',
#   'read',
#   'educating',
#   'funny',
#   'history',
#   'keeps'],
#  ['powerful', 'personal', 'branding', 'tips', 'digital', 'zero'],
#  ['powerful', 'personal', 'branding', 'tips', 'digital', 'zero'],
#  ['listen', 'atomic', 'clock', 'nist', 'ticking'],
#  ['microsoft', 'inform', 'government', 'spying'],
#  ['new', 'video'],
#  ['rt', 'rocking', 'views', 'likes'],
#  ['king', 'dark', 'summon', 'app', 'google'],
#  ['zaker',
#   'pro',
#   'azkar',
#   'muslim',
#   'pray',
#   'android',
#   'apps',
#   'google',
#   'play'],
#  ['write',
#   'android',
#   'application',
#   'patilvaibhavp99',
#   'want',
#   'integrate',
#   'google',
#   'auto',
#   'complete',
#   'place',
#   'api',
#   'android'],
#  ['takes', '58', 'minutes', 'google', 'course', 'google', 'modi'],
#  ['universo', 'google', 'reader', 'potente'],
#  ['rt', 'check'],
#  ['rt', 'calendar'],
#  ['order', 'refer'],
#  ['european', 'tour', 'fantasy', 'golf', 'app', 'android'],
#  ['associated', 'vikings', 'nfc', 'hold', 'beat', 'packers'],
#  ['king', 'dark', 'summon', 'app', 'google'],
#  ['new', 'event', 'new', 'rank', 'app', 'google'],
#  ['looked', 'google', 'gave'],
#  ['just', 'received', 'legendary'],
#  ['new', 'event', 'new', 'rank', 'app', 'google'],
#  ...]

# %%
model = models.Word2Vec(sentences, size = 100, window = 3, min_count = 5, workers = 4)
# Out:
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay

# %%
model.most_similar(positive = ['girl'])
# Out:
# [('million', 0.9831863641738892),
#  ('money', 0.98276287317276),
#  ('protect', 0.9826767444610596),
#  ('oil', 0.9824026226997375),
#  ('alerts', 0.9820623397827148),
#  ('tehran', 0.9820042848587036),
#  ('proactive', 0.9819892644882202),
#  ('injured', 0.9819713830947876),
#  ('nice', 0.9819350242614746),
#  ('smart', 0.9818744659423828)]
